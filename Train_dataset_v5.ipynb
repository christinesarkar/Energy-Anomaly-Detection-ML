# %% [markdown]
# In this colab notebook I am exploring, vizualizing and training the train dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1.Importing libraries:

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from tqdm import tqdm, trange
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import metrics
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from catboost import CatBoostClassifier
import lightgbm as lgb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Loading Dataset

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/energy-anomaly-detection/train.csv')
train.head()
# Out:
#    building_id            timestamp  meter_reading  anomaly
# 0            1  2016-01-01 00:00:00            NaN        0
# 1           32  2016-01-01 00:00:00            NaN        0
# 2           41  2016-01-01 00:00:00            NaN        0
# 3           55  2016-01-01 00:00:00            NaN        0
# 4           69  2016-01-01 00:00:00            NaN        0

# %% [markdown]
# in the first 5 rows it is seen that there are null values in the meter reading column.

# %%
train.shape
# Out:
# (1749494, 4)

# %% [markdown]
# getting the null values

# %%
train.isnull().sum()
# Out:
# building_id           0
# timestamp             0
# meter_reading    107653
# anomaly               0
# dtype: int64

# %% [markdown]
# # 3. Vizualization:

# %% [markdown]
# Vizualizing the proportion of null values in the dataset with a pie chart.

# %%
missing_values = train.isnull().sum().sum()
plt.pie([missing_values, train.shape[0]-missing_values], labels=['Null', 'Filled']\
        , colors=sb.color_palette('Accent'), autopct='%.0f%%')
plt.title('Percentage of Null Values')
plt.show()

# %% [markdown]
# total 6% is null values in the dataset and they are in meter_reading column.

# %%
plt.subplots(figsize=(15,10))
plt.subplot(1,2,1)
sb.countplot(x=train['anomaly'], palette= 'Accent')
plt.title('Distribution of Anomalies')
plt.subplot(1,2,2)
data = train['anomaly'].value_counts()
plt.pie(data, labels=['Normal', 'Anomalous'], colors=sb.color_palette('pastel'), autopct='%.0f%%')

plt.show()

# %% [markdown]
# In anomaly detection problems, data imbalance is common because anomalies are rare events that do not occur frequently. If they did occur often, it would suggest a different underlying issue.

# %%
# Converting 'meter_reading' to numeric, handling potential errors
train['meter_reading'] = pd.to_numeric(train['meter_reading'], errors='coerce')

# Calculating the mean meter reading per building
mean_reading = train.groupby('building_id')['meter_reading'].mean()

print(mean_reading)
# Out:
# building_id
# 1        35.267879
# 32       98.400360
# 41       61.162877
# 55       33.911298
# 69       30.782749
#            ...
# 1316     52.996412
# 1318    158.332296
# 1319    132.040616
# 1323    182.157895
# 1353      7.024886
# Name: meter_reading, Length: 200, dtype: float64

# %%
plt.figure(figsize=(10, 10))
mean_reading.plot(kind='bar', color= 'green')
plt.xticks(ticks=[], labels=[])
plt.show()

# %% [markdown]
# Here, with idxmax() I am finding out which building id has the highest mean meter reading.

# %%
mean_reading.idxmax()
# Out:
# 801

# %% [markdown]
# **Feature Engineering:**
#
#
# Breaking down timestamp column into date and time

# %%
def split_timestamp(df):
    split_data = df['timestamp'].str.split(' ', n=1, expand=True)
    df['date'] = split_data[0]
    df['hour'] = split_data[1].str[:2].astype(int)
    df = df.drop(columns=['timestamp'])
    return df

train = split_timestamp(train)
train.head()
# Out:
#    building_id  meter_reading  anomaly        date  hour
# 0            1            NaN        0  2016-01-01     0
# 1           32            NaN        0  2016-01-01     0
# 2           41            NaN        0  2016-01-01     0
# 3           55            NaN        0  2016-01-01     0
# 4           69            NaN        0  2016-01-01     0

# %%
#'train' already has 'date' and 'hour' columns from a previous call to add_date_time

plt.figure(figsize=(10, 5))
train.groupby('hour')['meter_reading'].mean().plot(kind ='bar', color='green')  # Calculating mean on numeric column
plt.title('Mean usage hourly.', fontsize=10)
plt.show()

# %%
def extract_month_day(df):
    df['month'] = df['date'].str.slice(5, 7).astype(int)
    df['day'] = df['date'].str.slice(-2).astype(int)
    df = df.drop(columns=['date'])
    return df

train = extract_month_day(train)
train.head()
# Out:
#    building_id  meter_reading  anomaly  hour  month  day
# 0            1            NaN        0     0      1    1
# 1           32            NaN        0     0      1    1
# 2           41            NaN        0     0      1    1
# 3           55            NaN        0     0      1    1
# 4           69            NaN        0     0      1    1

# %%
plt.figure(figsize=(10, 5))
train.groupby('month')['meter_reading'].mean().plot(kind='bar', color='green')
plt.title('Average Monthly Meter Reading', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10, 5))
train.groupby('day')['meter_reading'].mean().plot(kind='bar', color='green')
plt.title('Average Daily Meter Reading', fontsize=20)
plt.show()

# %% [markdown]
# Getting the 5 rows of the dataset after splitting timestamp

# %%
train.head()
# Out:
#    building_id  meter_reading  anomaly  hour  month  day
# 0            1            NaN        0     0      1    1
# 1           32            NaN        0     0      1    1
# 2           41            NaN        0     0      1    1
# 3           55            NaN        0     0      1    1
# 4           69            NaN        0     0      1    1

# %%
import datetime as dt
# Function to determine if a date falls on a weekend or a weekday
def is_weekend(year, month, day):
    date = dt.datetime(year, month, day)
    return 1 if date.weekday() > 4 else 0

# Adding a new feature to denote weekends
train['weekend'] = train.apply(lambda row: is_weekend(2016, int(row['month']), int(row['day'])), axis=1)
train.head()
# Out:
#    building_id  meter_reading  anomaly  hour  month  day  weekend
# 0            1            NaN        0     0      1    1        0
# 1           32            NaN        0     0      1    1        0
# 2           41            NaN        0     0      1    1        0
# 3           55            NaN        0     0      1    1        0
# 4           69            NaN        0     0      1    1        0

# %%
train['weekend'].value_counts()
# Out:
# weekend
# 0    1247563
# 1     501931
# Name: count, dtype: int64

# %%
average_readings = train.groupby('weekend')['meter_reading'].mean()
plt.pie(average_readings, labels=['Weekday average Usage', 'Weekend average Usage'], colors=sb.color_palette('Accent'))
plt.show()

# %% [markdown]
# Usage over the weekdays are more than weekend.

# %% [markdown]
# # 4. Preprocessing

# %% [markdown]
# **Imputing Null values**

# %%
def fill_missing_values(dataset):
    # Calculating the mean meter reading for each building
    average_readings = dataset.groupby('building_id')['meter_reading'].mean()

    # Looping over each building ID and filling missing values with the corresponding mean meter reading
    for building in average_readings.index:
        dataset.loc[dataset['building_id'] == building] = dataset.loc[dataset['building_id'] == building].fillna(average_readings[building])

    return dataset

train = fill_missing_values(train)

# %% [markdown]
# By Grouping the data by building_id and calculating the mean of the meter_reading for each building, this mean value will be used to fill in any missing meter_reading values within that specific building.
# For each building, identified by its building_id, the code checks if there are any missing values (NaN) in the meter_reading column.If there are missing values, it fills these with the mean meter_reading calculated in the first step for that particular building.
# The dataset is then updated in place with the filled values.
# Finally, the function returns the updated dataset where all missing meter_reading values have been replaced with the mean values specific to each building.

# %% [markdown]
# **Equalizing positive and negative examples:**

# %% [markdown]
# Due to imbalance in the data, it's crucial to equalize the positive and negative examples. Without this balance, the model will struggle to generalize the positive examples, which is the primary objective.

# %%
# Separating the negative and positive examples
negative_examples = train[train['anomaly'] == 0]
positive_examples = train[train['anomaly'] == 1]

# Printing the shapes of the negative and positive datasets
print(negative_examples.shape, positive_examples.shape)

# Sampling two subsets of the negative examples
negative_sample1 = negative_examples.sample(n=37296, random_state=10)
negative_sample2 = negative_examples.sample(n=37296, random_state=20)

# Combining the samples and the positive examples
balanced_dataset = pd.concat([negative_sample1, positive_examples, negative_sample2, positive_examples], axis=0)

# Print the shape of the balanced dataset
print(balanced_dataset.shape)
# Out:
# (1712198, 7) (37296, 7)
# (149184, 7)

# %% [markdown]
# Although this method prevents my model from seeing the entire dataset, it helps improve the model's ability to generalize to both positive and negative examples.

# %%
feature_set = balanced_dataset.drop(['building_id', 'anomaly'], axis=1)
target_variable = balanced_dataset['anomaly']

# %%
X_train, X_val, Y_train, Y_val = train_test_split(feature_set, target_variable, test_size = 0.01, random_state=10)
print(X_train.shape, X_val.shape)

# Normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
# Out:
# (147692, 5) (1492, 5)

# %% [markdown]
# feature_set: This variable contains all the features (independent variables) used for training the model, excluding building_id and anomaly.
# target_variable: This variable contains the target variable (dependent variable) that the model aims to predict, which is anomaly.

# %% [markdown]
# # 5. Model

# %% [markdown]
# I am using Logistic Regression, XGB classifier, decesion tree, HistGradientBoosting, CatBoost and LightGBM to see which can give best accuracy for this dataset.

# %%
from sklearn.metrics import accuracy_score
# Defining the models to be evaluated
model_list1 = [LogisticRegression(), DecisionTreeClassifier(), XGBClassifier(), HistGradientBoostingClassifier(), CatBoostClassifier(), lgb.LGBMClassifier(n_estimators=100)]

# Iterating over each model to train and evaluate
for model in model_list1:
    # Fit the model on the training data
    model.fit(X_train, Y_train)

    # Printing model details and evaluation metrics
    print(f'Model: {model}')
    train_predictions = model.predict(X_train)
    val_predictions = model.predict(X_val)
    print('Training:', accuracy_score(Y_train, train_predictions))
    print('Validation:', accuracy_score(Y_val, val_predictions))
    print()
# Out:
# Model: LogisticRegression()
# Training: 0.5497386452888443
# Validation: 0.5288203753351206
#
# Model: DecisionTreeClassifier()
# Training: 0.9996953118652331
# Validation: 0.9658176943699732
#
# Model: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# Training: 0.8838528830268396
# Validation: 0.8900804289544236
#
# Model: HistGradientBoostingClassifier()
# Training: 0.848258538038621
# Validation: 0.8626005361930295
#
# Learning rate set to 0.086946
# 0:	learn: 0.6427706	total: 78.8ms	remaining: 1m 18s
# 1:	learn: 0.6022555	total: 113ms	remaining: 56.2s
# 2:	learn: 0.5738600	total: 142ms	remaining: 47.1s
# 3:	learn: 0.5506539	total: 175ms	remaining: 43.5s
# 4:	learn: 0.5195984	total: 226ms	remaining: 45s
# 5:	learn: 0.5087864	total: 259ms	remaining: 43s
# 6:	learn: 0.5001758	total: 288ms	remaining: 40.9s
# 7:	learn: 0.4940132	total: 319ms	remaining: 39.6s
# 8:	learn: 0.4882223	total: 348ms	remaining: 38.3s
# 9:	learn: 0.4790298	total: 384ms	remaining: 38s
# 10:	learn: 0.4729998	total: 414ms	remaining: 37.2s
# 11:	learn: 0.4698226	total: 443ms	remaining: 36.5s
# 12:	learn: 0.4671436	total: 475ms	remaining: 36.1s
# 13:	learn: 0.4635790	total: 502ms	remaining: 35.4s
# 14:	learn: 0.4609367	total: 535ms	remaining: 35.1s
# 15:	learn: 0.4584063	total: 569ms	remaining: 35s
# 16:	learn: 0.4572097	total: 595ms	remaining: 34.4s
# 17:	learn: 0.4556517	total: 624ms	remaining: 34s
# 18:	learn: 0.4539942	total: 651ms	remaining: 33.6s
# 19:	learn: 0.4524628	total: 680ms	remaining: 33.3s
# 20:	learn: 0.4511240	total: 706ms	remaining: 32.9s
# 21:	learn: 0.4493927	total: 733ms	remaining: 32.6s
# 22:	learn: 0.4481194	total: 771ms	remaining: 32.7s
# 23:	learn: 0.4468785	total: 800ms	remaining: 32.5s
# 24:	learn: 0.4462613	total: 828ms	remaining: 32.3s
# 25:	learn: 0.4450160	total: 856ms	remaining: 32.1s
# 26:	learn: 0.4440013	total: 883ms	remaining: 31.8s
# 27:	learn: 0.4429068	total: 916ms	remaining: 31.8s
# 28:	learn: 0.4421541	total: 945ms	remaining: 31.6s
# 29:	learn: 0.4410796	total: 985ms	remaining: 31.9s
# 30:	learn: 0.4404621	total: 1.02s	remaining: 31.8s
# 31:	learn: 0.4395058	total: 1.05s	remaining: 31.6s
# 32:	learn: 0.4382206	total: 1.08s	remaining: 31.6s
# 33:	learn: 0.4377905	total: 1.11s	remaining: 31.7s
# 34:	learn: 0.4370513	total: 1.15s	remaining: 31.6s
# 35:	learn: 0.4363745	total: 1.18s	remaining: 31.6s
# 36:	learn: 0.4357575	total: 1.23s	remaining: 32.1s
# 37:	learn: 0.4351703	total: 1.27s	remaining: 32.3s
# 38:	learn: 0.4343039	total: 1.31s	remaining: 32.3s
# 39:	learn: 0.4338808	total: 1.34s	remaining: 32.1s
# 40:	learn: 0.4332932	total: 1.37s	remaining: 32s
# 41:	learn: 0.4327780	total: 1.4s	remaining: 31.9s
# 42:	learn: 0.4323686	total: 1.43s	remaining: 31.9s
# 43:	learn: 0.4316748	total: 1.47s	remaining: 31.9s
# 44:	learn: 0.4308945	total: 1.5s	remaining: 31.9s
# 45:	learn: 0.4301275	total: 1.53s	remaining: 31.8s
# 46:	learn: 0.4292951	total: 1.57s	remaining: 31.8s
# 47:	learn: 0.4284736	total: 1.6s	remaining: 31.7s
# 48:	learn: 0.4279247	total: 1.63s	remaining: 31.7s
# 49:	learn: 0.4270810	total: 1.67s	remaining: 31.7s
# 50:	learn: 0.4265261	total: 1.7s	remaining: 31.6s
# 51:	learn: 0.4257992	total: 1.73s	remaining: 31.5s
# 52:	learn: 0.4252627	total: 1.77s	remaining: 31.6s
# 53:	learn: 0.4248422	total: 1.8s	remaining: 31.6s
# 54:	learn: 0.4240625	total: 1.84s	remaining: 31.5s
# 55:	learn: 0.4237179	total: 1.87s	remaining: 31.5s
# 56:	learn: 0.4230156	total: 1.9s	remaining: 31.5s
# 57:	learn: 0.4223721	total: 1.94s	remaining: 31.4s
# 58:	learn: 0.4215290	total: 1.97s	remaining: 31.4s
# 59:	learn: 0.4210186	total: 2s	remaining: 31.4s
# 60:	learn: 0.4204407	total: 2.04s	remaining: 31.3s
# 61:	learn: 0.4200123	total: 2.06s	remaining: 31.3s
# 62:	learn: 0.4196451	total: 2.1s	remaining: 31.3s
# 63:	learn: 0.4191411	total: 2.13s	remaining: 31.2s
# 64:	learn: 0.4187112	total: 2.16s	remaining: 31.1s
# 65:	learn: 0.4180404	total: 2.2s	remaining: 31.1s
# 66:	learn: 0.4175949	total: 2.24s	remaining: 31.2s
# 67:	learn: 0.4170629	total: 2.29s	remaining: 31.4s
# 68:	learn: 0.4165002	total: 2.33s	remaining: 31.4s
# 69:	learn: 0.4161348	total: 2.36s	remaining: 31.3s
# 70:	learn: 0.4157136	total: 2.38s	remaining: 31.2s
# 71:	learn: 0.4153104	total: 2.41s	remaining: 31.1s
# 72:	learn: 0.4149825	total: 2.45s	remaining: 31.1s
# 73:	learn: 0.4146288	total: 2.48s	remaining: 31.1s
# 74:	learn: 0.4142646	total: 2.51s	remaining: 31s
# 75:	learn: 0.4139208	total: 2.55s	remaining: 31s
# 76:	learn: 0.4135736	total: 2.58s	remaining: 30.9s
# 77:	learn: 0.4132061	total: 2.61s	remaining: 30.8s
# 78:	learn: 0.4126992	total: 2.64s	remaining: 30.8s
# 79:	learn: 0.4122908	total: 2.68s	remaining: 30.8s
# 80:	learn: 0.4119692	total: 2.71s	remaining: 30.7s
# 81:	learn: 0.4115726	total: 2.74s	remaining: 30.7s
# 82:	learn: 0.4109843	total: 2.78s	remaining: 30.7s
# 83:	learn: 0.4107265	total: 2.8s	remaining: 30.6s
# 84:	learn: 0.4103934	total: 2.83s	remaining: 30.5s
# 85:	learn: 0.4099453	total: 2.87s	remaining: 30.5s
# 86:	learn: 0.4095057	total: 2.9s	remaining: 30.5s
# 87:	learn: 0.4091772	total: 2.93s	remaining: 30.4s
# 88:	learn: 0.4090045	total: 2.96s	remaining: 30.3s
# 89:	learn: 0.4086285	total: 3s	remaining: 30.3s
# 90:	learn: 0.4082987	total: 3.03s	remaining: 30.2s
# 91:	learn: 0.4077466	total: 3.06s	remaining: 30.2s
# 92:	learn: 0.4072495	total: 3.08s	remaining: 30.1s
# 93:	learn: 0.4068340	total: 3.12s	remaining: 30.1s
# 94:	learn: 0.4064377	total: 3.15s	remaining: 30s
# 95:	learn: 0.4058207	total: 3.18s	remaining: 30s
# 96:	learn: 0.4055889	total: 3.22s	remaining: 30s
# 97:	learn: 0.4052789	total: 3.25s	remaining: 29.9s
# 98:	learn: 0.4048391	total: 3.3s	remaining: 30.1s
# 99:	learn: 0.4046274	total: 3.34s	remaining: 30s
# 100:	learn: 0.4042113	total: 3.37s	remaining: 30s
# 101:	learn: 0.4038890	total: 3.4s	remaining: 29.9s
# 102:	learn: 0.4035940	total: 3.44s	remaining: 30s
# 103:	learn: 0.4031975	total: 3.47s	remaining: 29.9s
# 104:	learn: 0.4026538	total: 3.51s	remaining: 29.9s
# 105:	learn: 0.4023088	total: 3.54s	remaining: 29.8s
# 106:	learn: 0.4015153	total: 3.58s	remaining: 29.9s
# 107:	learn: 0.4012274	total: 3.61s	remaining: 29.8s
# 108:	learn: 0.4009639	total: 3.65s	remaining: 29.8s
# 109:	learn: 0.4004529	total: 3.68s	remaining: 29.8s
# 110:	learn: 0.4001914	total: 3.71s	remaining: 29.7s
# 111:	learn: 0.3998714	total: 3.74s	remaining: 29.6s
# 112:	learn: 0.3996342	total: 3.77s	remaining: 29.6s
# 113:	learn: 0.3992008	total: 3.8s	remaining: 29.6s
# 114:	learn: 0.3987031	total: 3.83s	remaining: 29.5s
# 115:	learn: 0.3983175	total: 3.87s	remaining: 29.5s
# 116:	learn: 0.3981041	total: 3.9s	remaining: 29.4s
# 117:	learn: 0.3976811	total: 3.93s	remaining: 29.4s
# 118:	learn: 0.3973637	total: 3.96s	remaining: 29.4s
# 119:	learn: 0.3970585	total: 4s	remaining: 29.3s
# 120:	learn: 0.3963047	total: 4.03s	remaining: 29.3s
# 121:	learn: 0.3959000	total: 4.06s	remaining: 29.2s
# 122:	learn: 0.3954457	total: 4.1s	remaining: 29.2s
# 123:	learn: 0.3951151	total: 4.13s	remaining: 29.2s
# 124:	learn: 0.3948773	total: 4.16s	remaining: 29.1s
# 125:	learn: 0.3944701	total: 4.2s	remaining: 29.2s
# 126:	learn: 0.3938595	total: 4.24s	remaining: 29.1s
# 127:	learn: 0.3935895	total: 4.27s	remaining: 29.1s
# 128:	learn: 0.3934219	total: 4.32s	remaining: 29.2s
# 129:	learn: 0.3932437	total: 4.35s	remaining: 29.1s
# 130:	learn: 0.3929616	total: 4.38s	remaining: 29.1s
# 131:	learn: 0.3926917	total: 4.41s	remaining: 29s
# 132:	learn: 0.3925226	total: 4.45s	remaining: 29s
# 133:	learn: 0.3922366	total: 4.48s	remaining: 29s
# 134:	learn: 0.3918155	total: 4.51s	remaining: 28.9s
# 135:	learn: 0.3915028	total: 4.55s	remaining: 28.9s
# 136:	learn: 0.3913773	total: 4.58s	remaining: 28.9s
# 137:	learn: 0.3910193	total: 4.61s	remaining: 28.8s
# 138:	learn: 0.3906759	total: 4.64s	remaining: 28.7s
# 139:	learn: 0.3905298	total: 4.67s	remaining: 28.7s
# 140:	learn: 0.3900945	total: 4.7s	remaining: 28.7s
# 141:	learn: 0.3899215	total: 4.73s	remaining: 28.6s
# 142:	learn: 0.3897469	total: 4.77s	remaining: 28.6s
# 143:	learn: 0.3894880	total: 4.8s	remaining: 28.5s
# 144:	learn: 0.3892677	total: 4.83s	remaining: 28.5s
# 145:	learn: 0.3888914	total: 4.86s	remaining: 28.4s
# 146:	learn: 0.3887036	total: 4.89s	remaining: 28.4s
# 147:	learn: 0.3885070	total: 4.92s	remaining: 28.3s
# 148:	learn: 0.3881811	total: 4.95s	remaining: 28.3s
# 149:	learn: 0.3880169	total: 4.99s	remaining: 28.3s
# 150:	learn: 0.3877628	total: 5.02s	remaining: 28.2s
# 151:	learn: 0.3875725	total: 5.05s	remaining: 28.2s
# 152:	learn: 0.3873355	total: 5.08s	remaining: 28.1s
# 153:	learn: 0.3871588	total: 5.11s	remaining: 28.1s
# 154:	learn: 0.3867947	total: 5.14s	remaining: 28s
# 155:	learn: 0.3864992	total: 5.17s	remaining: 28s
# 156:	learn: 0.3862021	total: 5.21s	remaining: 28s
# 157:	learn: 0.3858928	total: 5.25s	remaining: 28s
# 158:	learn: 0.3856114	total: 5.28s	remaining: 27.9s
# 159:	learn: 0.3854269	total: 5.31s	remaining: 27.9s
# 160:	learn: 0.3852094	total: 5.37s	remaining: 28s
# 161:	learn: 0.3849946	total: 5.4s	remaining: 27.9s
# 162:	learn: 0.3845093	total: 5.44s	remaining: 27.9s
# 163:	learn: 0.3843003	total: 5.47s	remaining: 27.9s
# 164:	learn: 0.3839949	total: 5.5s	remaining: 27.9s
# 165:	learn: 0.3836935	total: 5.54s	remaining: 27.8s
# 166:	learn: 0.3834592	total: 5.58s	remaining: 27.8s
# 167:	learn: 0.3832025	total: 5.61s	remaining: 27.8s
# 168:	learn: 0.3830575	total: 5.63s	remaining: 27.7s
# 169:	learn: 0.3825862	total: 5.68s	remaining: 27.7s
# 170:	learn: 0.3822016	total: 5.71s	remaining: 27.7s
# 171:	learn: 0.3820389	total: 5.75s	remaining: 27.7s
# 172:	learn: 0.3817373	total: 5.78s	remaining: 27.6s
# 173:	learn: 0.3815490	total: 5.82s	remaining: 27.6s
# 174:	learn: 0.3813668	total: 5.85s	remaining: 27.6s
# 175:	learn: 0.3811599	total: 5.87s	remaining: 27.5s
# 176:	learn: 0.3809737	total: 5.94s	remaining: 27.6s
# 177:	learn: 0.3807283	total: 5.99s	remaining: 27.6s
# 178:	learn: 0.3803901	total: 6.04s	remaining: 27.7s
# 179:	learn: 0.3802459	total: 6.1s	remaining: 27.8s
# 180:	learn: 0.3800282	total: 6.17s	remaining: 27.9s
# 181:	learn: 0.3797570	total: 6.22s	remaining: 27.9s
# 182:	learn: 0.3795730	total: 6.27s	remaining: 28s
# 183:	learn: 0.3792772	total: 6.35s	remaining: 28.2s
# 184:	learn: 0.3790708	total: 6.45s	remaining: 28.4s
# 185:	learn: 0.3789282	total: 6.53s	remaining: 28.6s
# 186:	learn: 0.3788018	total: 6.61s	remaining: 28.7s
# 187:	learn: 0.3785945	total: 6.68s	remaining: 28.9s
# 188:	learn: 0.3783047	total: 6.76s	remaining: 29s
# 189:	learn: 0.3779612	total: 6.84s	remaining: 29.2s
# 190:	learn: 0.3777407	total: 6.92s	remaining: 29.3s
# 191:	learn: 0.3772089	total: 6.99s	remaining: 29.4s
# 192:	learn: 0.3769148	total: 7.07s	remaining: 29.6s
# 193:	learn: 0.3766261	total: 7.14s	remaining: 29.7s
# 194:	learn: 0.3765098	total: 7.19s	remaining: 29.7s
# 195:	learn: 0.3763490	total: 7.26s	remaining: 29.8s
# 196:	learn: 0.3760635	total: 7.31s	remaining: 29.8s
# 197:	learn: 0.3758719	total: 7.35s	remaining: 29.8s
# 198:	learn: 0.3756213	total: 7.42s	remaining: 29.9s
# 199:	learn: 0.3754148	total: 7.49s	remaining: 30s
# 200:	learn: 0.3750493	total: 7.57s	remaining: 30.1s
# 201:	learn: 0.3746901	total: 7.63s	remaining: 30.1s
# 202:	learn: 0.3744387	total: 7.68s	remaining: 30.2s
# 203:	learn: 0.3742362	total: 7.74s	remaining: 30.2s
# 204:	learn: 0.3740915	total: 7.82s	remaining: 30.3s
# 205:	learn: 0.3738511	total: 7.89s	remaining: 30.4s
# 206:	learn: 0.3735899	total: 7.94s	remaining: 30.4s
# 207:	learn: 0.3734458	total: 7.99s	remaining: 30.4s
# 208:	learn: 0.3732253	total: 8.04s	remaining: 30.4s
# 209:	learn: 0.3730824	total: 8.11s	remaining: 30.5s
# 210:	learn: 0.3727297	total: 8.21s	remaining: 30.7s
# 211:	learn: 0.3724263	total: 8.31s	remaining: 30.9s
# 212:	learn: 0.3722471	total: 8.39s	remaining: 31s
# 213:	learn: 0.3721198	total: 8.47s	remaining: 31.1s
# 214:	learn: 0.3719013	total: 8.56s	remaining: 31.3s
# 215:	learn: 0.3716422	total: 8.63s	remaining: 31.3s
# 216:	learn: 0.3714160	total: 8.7s	remaining: 31.4s
# 217:	learn: 0.3711752	total: 8.78s	remaining: 31.5s
# 218:	learn: 0.3709120	total: 8.85s	remaining: 31.6s
# 219:	learn: 0.3707477	total: 8.93s	remaining: 31.7s
# 220:	learn: 0.3706104	total: 9s	remaining: 31.7s
# 221:	learn: 0.3703834	total: 9.07s	remaining: 31.8s
# 222:	learn: 0.3702596	total: 9.15s	remaining: 31.9s
# 223:	learn: 0.3699770	total: 9.23s	remaining: 32s
# 224:	learn: 0.3697056	total: 9.32s	remaining: 32.1s
# 225:	learn: 0.3695241	total: 9.4s	remaining: 32.2s
# 226:	learn: 0.3690683	total: 9.48s	remaining: 32.3s
# 227:	learn: 0.3688092	total: 9.56s	remaining: 32.4s
# 228:	learn: 0.3687117	total: 9.63s	remaining: 32.4s
# 229:	learn: 0.3684818	total: 9.71s	remaining: 32.5s
# 230:	learn: 0.3683663	total: 9.75s	remaining: 32.5s
# 231:	learn: 0.3681268	total: 9.83s	remaining: 32.5s
# 232:	learn: 0.3678984	total: 9.89s	remaining: 32.5s
# 233:	learn: 0.3675838	total: 9.95s	remaining: 32.6s
# 234:	learn: 0.3672461	total: 10s	remaining: 32.6s
# 235:	learn: 0.3668689	total: 10.1s	remaining: 32.7s
# 236:	learn: 0.3666458	total: 10.2s	remaining: 32.8s
# 237:	learn: 0.3664464	total: 10.3s	remaining: 32.9s
# 238:	learn: 0.3663055	total: 10.3s	remaining: 32.9s
# 239:	learn: 0.3661400	total: 10.4s	remaining: 33s
# 240:	learn: 0.3659348	total: 10.5s	remaining: 33.1s
# 241:	learn: 0.3656978	total: 10.6s	remaining: 33.2s
# 242:	learn: 0.3654830	total: 10.7s	remaining: 33.2s
# 243:	learn: 0.3652092	total: 10.7s	remaining: 33.3s
# 244:	learn: 0.3649525	total: 10.8s	remaining: 33.4s
# 245:	learn: 0.3647808	total: 10.9s	remaining: 33.4s
# 246:	learn: 0.3645180	total: 11s	remaining: 33.5s
# 247:	learn: 0.3642915	total: 11.1s	remaining: 33.6s
# 248:	learn: 0.3640595	total: 11.2s	remaining: 33.6s
# 249:	learn: 0.3637824	total: 11.2s	remaining: 33.7s
# 250:	learn: 0.3633995	total: 11.3s	remaining: 33.7s
# 251:	learn: 0.3632486	total: 11.4s	remaining: 33.8s
# 252:	learn: 0.3630281	total: 11.5s	remaining: 33.8s
# 253:	learn: 0.3628267	total: 11.5s	remaining: 33.9s
# 254:	learn: 0.3625337	total: 11.6s	remaining: 33.9s
# 255:	learn: 0.3623661	total: 11.7s	remaining: 33.9s
# 256:	learn: 0.3622018	total: 11.7s	remaining: 33.8s
# 257:	learn: 0.3621030	total: 11.7s	remaining: 33.7s
# 258:	learn: 0.3619103	total: 11.8s	remaining: 33.6s
# 259:	learn: 0.3617843	total: 11.8s	remaining: 33.6s
# 260:	learn: 0.3615872	total: 11.8s	remaining: 33.5s
# 261:	learn: 0.3614384	total: 11.9s	remaining: 33.4s
# 262:	learn: 0.3612319	total: 11.9s	remaining: 33.3s
# 263:	learn: 0.3610323	total: 11.9s	remaining: 33.2s
# 264:	learn: 0.3609014	total: 12s	remaining: 33.2s
# 265:	learn: 0.3608217	total: 12s	remaining: 33.1s
# 266:	learn: 0.3606190	total: 12s	remaining: 33s
# 267:	learn: 0.3603826	total: 12.1s	remaining: 32.9s
# 268:	learn: 0.3602051	total: 12.1s	remaining: 32.8s
# 269:	learn: 0.3600013	total: 12.1s	remaining: 32.8s
# 270:	learn: 0.3598283	total: 12.2s	remaining: 32.7s
# 271:	learn: 0.3596455	total: 12.2s	remaining: 32.6s
# 272:	learn: 0.3595008	total: 12.2s	remaining: 32.6s
# 273:	learn: 0.3592782	total: 12.3s	remaining: 32.5s
# 274:	learn: 0.3591257	total: 12.3s	remaining: 32.4s
# 275:	learn: 0.3590094	total: 12.3s	remaining: 32.3s
# 276:	learn: 0.3588133	total: 12.4s	remaining: 32.2s
# 277:	learn: 0.3586927	total: 12.4s	remaining: 32.2s
# 278:	learn: 0.3584297	total: 12.4s	remaining: 32.1s
# 279:	learn: 0.3582701	total: 12.5s	remaining: 32s
# 280:	learn: 0.3581195	total: 12.5s	remaining: 32s
# 281:	learn: 0.3579608	total: 12.5s	remaining: 31.9s
# 282:	learn: 0.3577874	total: 12.6s	remaining: 31.8s
# 283:	learn: 0.3576527	total: 12.6s	remaining: 31.8s
# 284:	learn: 0.3574709	total: 12.6s	remaining: 31.7s
# 285:	learn: 0.3572912	total: 12.7s	remaining: 31.7s
# 286:	learn: 0.3571359	total: 12.7s	remaining: 31.6s
# 287:	learn: 0.3569760	total: 12.8s	remaining: 31.5s
# 288:	learn: 0.3568653	total: 12.8s	remaining: 31.4s
# 289:	learn: 0.3566949	total: 12.8s	remaining: 31.4s
# 290:	learn: 0.3565797	total: 12.8s	remaining: 31.3s
# 291:	learn: 0.3563860	total: 12.9s	remaining: 31.2s
# 292:	learn: 0.3562501	total: 12.9s	remaining: 31.1s
# 293:	learn: 0.3561048	total: 12.9s	remaining: 31.1s
# 294:	learn: 0.3559757	total: 13s	remaining: 31s
# 295:	learn: 0.3558168	total: 13s	remaining: 31s
# 296:	learn: 0.3556441	total: 13s	remaining: 30.9s
# 297:	learn: 0.3554387	total: 13.1s	remaining: 30.8s
# 298:	learn: 0.3552954	total: 13.1s	remaining: 30.8s
# 299:	learn: 0.3551745	total: 13.2s	remaining: 30.7s
# 300:	learn: 0.3548911	total: 13.2s	remaining: 30.6s
# 301:	learn: 0.3545709	total: 13.2s	remaining: 30.6s
# 302:	learn: 0.3544335	total: 13.3s	remaining: 30.5s
# 303:	learn: 0.3542967	total: 13.3s	remaining: 30.4s
# 304:	learn: 0.3542217	total: 13.3s	remaining: 30.4s
# 305:	learn: 0.3540692	total: 13.4s	remaining: 30.3s
# 306:	learn: 0.3539574	total: 13.4s	remaining: 30.2s
# 307:	learn: 0.3537354	total: 13.4s	remaining: 30.2s
# 308:	learn: 0.3536010	total: 13.5s	remaining: 30.1s
# 309:	learn: 0.3534553	total: 13.5s	remaining: 30s
# 310:	learn: 0.3533056	total: 13.5s	remaining: 30s
# 311:	learn: 0.3531725	total: 13.6s	remaining: 29.9s
# 312:	learn: 0.3530017	total: 13.6s	remaining: 29.8s
# 313:	learn: 0.3528720	total: 13.6s	remaining: 29.8s
# 314:	learn: 0.3527289	total: 13.7s	remaining: 29.7s
# 315:	learn: 0.3525724	total: 13.7s	remaining: 29.7s
# 316:	learn: 0.3524116	total: 13.7s	remaining: 29.6s
# 317:	learn: 0.3523025	total: 13.8s	remaining: 29.6s
# 318:	learn: 0.3521965	total: 13.8s	remaining: 29.5s
# 319:	learn: 0.3520551	total: 13.8s	remaining: 29.4s
# 320:	learn: 0.3519536	total: 13.9s	remaining: 29.4s
# 321:	learn: 0.3517607	total: 13.9s	remaining: 29.3s
# 322:	learn: 0.3516620	total: 13.9s	remaining: 29.2s
# 323:	learn: 0.3514235	total: 14s	remaining: 29.2s
# 324:	learn: 0.3513253	total: 14s	remaining: 29.1s
# 325:	learn: 0.3512001	total: 14s	remaining: 29s
# 326:	learn: 0.3510763	total: 14.1s	remaining: 29s
# 327:	learn: 0.3509835	total: 14.1s	remaining: 28.9s
# 328:	learn: 0.3508532	total: 14.1s	remaining: 28.8s
# 329:	learn: 0.3507021	total: 14.2s	remaining: 28.8s
# 330:	learn: 0.3504928	total: 14.2s	remaining: 28.7s
# 331:	learn: 0.3503546	total: 14.2s	remaining: 28.6s
# 332:	learn: 0.3501435	total: 14.3s	remaining: 28.6s
# 333:	learn: 0.3499514	total: 14.3s	remaining: 28.5s
# 334:	learn: 0.3498807	total: 14.3s	remaining: 28.5s
# 335:	learn: 0.3497381	total: 14.4s	remaining: 28.4s
# 336:	learn: 0.3495835	total: 14.4s	remaining: 28.3s
# 337:	learn: 0.3494594	total: 14.4s	remaining: 28.3s
# 338:	learn: 0.3493580	total: 14.5s	remaining: 28.2s
# 339:	learn: 0.3492166	total: 14.5s	remaining: 28.1s
# 340:	learn: 0.3490481	total: 14.5s	remaining: 28.1s
# 341:	learn: 0.3488172	total: 14.6s	remaining: 28s
# 342:	learn: 0.3486527	total: 14.6s	remaining: 28s
# 343:	learn: 0.3483472	total: 14.6s	remaining: 27.9s
# 344:	learn: 0.3482286	total: 14.7s	remaining: 27.9s
# 345:	learn: 0.3480888	total: 14.7s	remaining: 27.8s
# 346:	learn: 0.3479974	total: 14.8s	remaining: 27.8s
# 347:	learn: 0.3478436	total: 14.8s	remaining: 27.7s
# 348:	learn: 0.3477083	total: 14.8s	remaining: 27.6s
# 349:	learn: 0.3475715	total: 14.9s	remaining: 27.6s
# 350:	learn: 0.3474544	total: 14.9s	remaining: 27.5s
# 351:	learn: 0.3473003	total: 14.9s	remaining: 27.5s
# 352:	learn: 0.3471337	total: 14.9s	remaining: 27.4s
# 353:	learn: 0.3470200	total: 15s	remaining: 27.3s
# 354:	learn: 0.3469093	total: 15s	remaining: 27.3s
# 355:	learn: 0.3466768	total: 15s	remaining: 27.2s
# 356:	learn: 0.3465265	total: 15.1s	remaining: 27.2s
# 357:	learn: 0.3462681	total: 15.1s	remaining: 27.1s
# 358:	learn: 0.3461215	total: 15.2s	remaining: 27.1s
# 359:	learn: 0.3460356	total: 15.2s	remaining: 27s
# 360:	learn: 0.3458634	total: 15.2s	remaining: 26.9s
# 361:	learn: 0.3457524	total: 15.3s	remaining: 26.9s
# 362:	learn: 0.3456427	total: 15.3s	remaining: 26.8s
# 363:	learn: 0.3455167	total: 15.3s	remaining: 26.8s
# 364:	learn: 0.3453867	total: 15.4s	remaining: 26.7s
# 365:	learn: 0.3452604	total: 15.4s	remaining: 26.7s
# 366:	learn: 0.3450925	total: 15.4s	remaining: 26.6s
# 367:	learn: 0.3449975	total: 15.5s	remaining: 26.5s
# 368:	learn: 0.3448400	total: 15.5s	remaining: 26.5s
# 369:	learn: 0.3446951	total: 15.5s	remaining: 26.4s
# 370:	learn: 0.3445403	total: 15.6s	remaining: 26.4s
# 371:	learn: 0.3443914	total: 15.6s	remaining: 26.3s
# 372:	learn: 0.3442479	total: 15.6s	remaining: 26.2s
# 373:	learn: 0.3440488	total: 15.7s	remaining: 26.2s
# 374:	learn: 0.3439333	total: 15.7s	remaining: 26.1s
# 375:	learn: 0.3437223	total: 15.7s	remaining: 26.1s
# 376:	learn: 0.3436160	total: 15.8s	remaining: 26.1s
# 377:	learn: 0.3434631	total: 15.8s	remaining: 26s
# 378:	learn: 0.3432735	total: 15.8s	remaining: 25.9s
# 379:	learn: 0.3431788	total: 15.9s	remaining: 25.9s
# 380:	learn: 0.3430975	total: 15.9s	remaining: 25.8s
# 381:	learn: 0.3429444	total: 15.9s	remaining: 25.8s
# 382:	learn: 0.3428264	total: 16s	remaining: 25.7s
# 383:	learn: 0.3426577	total: 16s	remaining: 25.6s
# 384:	learn: 0.3425344	total: 16s	remaining: 25.6s
# 385:	learn: 0.3423543	total: 16.1s	remaining: 25.5s
# 386:	learn: 0.3422328	total: 16.1s	remaining: 25.5s
# 387:	learn: 0.3420787	total: 16.1s	remaining: 25.4s
# 388:	learn: 0.3419372	total: 16.2s	remaining: 25.4s
# 389:	learn: 0.3418257	total: 16.2s	remaining: 25.3s
# 390:	learn: 0.3417669	total: 16.2s	remaining: 25.3s
# 391:	learn: 0.3416758	total: 16.3s	remaining: 25.2s
# 392:	learn: 0.3414894	total: 16.3s	remaining: 25.2s
# 393:	learn: 0.3412999	total: 16.3s	remaining: 25.1s
# 394:	learn: 0.3412278	total: 16.4s	remaining: 25.1s
# 395:	learn: 0.3410880	total: 16.4s	remaining: 25s
# 396:	learn: 0.3410067	total: 16.4s	remaining: 24.9s
# 397:	learn: 0.3408608	total: 16.5s	remaining: 24.9s
# 398:	learn: 0.3407645	total: 16.5s	remaining: 24.8s
# 399:	learn: 0.3406035	total: 16.5s	remaining: 24.8s
# 400:	learn: 0.3404814	total: 16.6s	remaining: 24.7s
# 401:	learn: 0.3404166	total: 16.6s	remaining: 24.7s
# 402:	learn: 0.3403127	total: 16.6s	remaining: 24.6s
# 403:	learn: 0.3401590	total: 16.6s	remaining: 24.5s
# 404:	learn: 0.3399664	total: 16.7s	remaining: 24.5s
# 405:	learn: 0.3398416	total: 16.7s	remaining: 24.5s
# 406:	learn: 0.3397441	total: 16.8s	remaining: 24.4s
# 407:	learn: 0.3396386	total: 16.8s	remaining: 24.4s
# 408:	learn: 0.3394955	total: 16.8s	remaining: 24.3s
# 409:	learn: 0.3392985	total: 16.9s	remaining: 24.3s
# 410:	learn: 0.3392094	total: 16.9s	remaining: 24.2s
# 411:	learn: 0.3390322	total: 16.9s	remaining: 24.2s
# 412:	learn: 0.3389270	total: 17s	remaining: 24.1s
# 413:	learn: 0.3388422	total: 17s	remaining: 24.1s
# 414:	learn: 0.3387166	total: 17s	remaining: 24s
# 415:	learn: 0.3386079	total: 17.1s	remaining: 24s
# 416:	learn: 0.3384888	total: 17.1s	remaining: 23.9s
# 417:	learn: 0.3383186	total: 17.1s	remaining: 23.9s
# 418:	learn: 0.3382001	total: 17.2s	remaining: 23.8s
# 419:	learn: 0.3381238	total: 17.2s	remaining: 23.8s
# 420:	learn: 0.3379481	total: 17.2s	remaining: 23.7s
# 421:	learn: 0.3378182	total: 17.3s	remaining: 23.7s
# 422:	learn: 0.3377100	total: 17.3s	remaining: 23.6s
# 423:	learn: 0.3376140	total: 17.3s	remaining: 23.6s
# 424:	learn: 0.3374635	total: 17.4s	remaining: 23.5s
# 425:	learn: 0.3373550	total: 17.4s	remaining: 23.4s
# 426:	learn: 0.3372306	total: 17.4s	remaining: 23.4s
# 427:	learn: 0.3371075	total: 17.5s	remaining: 23.3s
# 428:	learn: 0.3370172	total: 17.5s	remaining: 23.3s
# 429:	learn: 0.3369098	total: 17.5s	remaining: 23.2s
# 430:	learn: 0.3367785	total: 17.6s	remaining: 23.2s
# 431:	learn: 0.3367023	total: 17.6s	remaining: 23.1s
# 432:	learn: 0.3365763	total: 17.6s	remaining: 23.1s
# 433:	learn: 0.3363863	total: 17.7s	remaining: 23s
# 434:	learn: 0.3362662	total: 17.7s	remaining: 23s
# 435:	learn: 0.3361505	total: 17.7s	remaining: 22.9s
# 436:	learn: 0.3359950	total: 17.8s	remaining: 22.9s
# 437:	learn: 0.3358856	total: 17.8s	remaining: 22.9s
# 438:	learn: 0.3358055	total: 17.8s	remaining: 22.8s
# 439:	learn: 0.3356985	total: 17.9s	remaining: 22.8s
# 440:	learn: 0.3355816	total: 17.9s	remaining: 22.7s
# 441:	learn: 0.3354956	total: 17.9s	remaining: 22.6s
# 442:	learn: 0.3353570	total: 18s	remaining: 22.6s
# 443:	learn: 0.3352059	total: 18s	remaining: 22.5s
# 444:	learn: 0.3351185	total: 18s	remaining: 22.5s
# 445:	learn: 0.3350005	total: 18.1s	remaining: 22.4s
# 446:	learn: 0.3348750	total: 18.1s	remaining: 22.4s
# 447:	learn: 0.3347244	total: 18.1s	remaining: 22.3s
# 448:	learn: 0.3346066	total: 18.2s	remaining: 22.3s
# 449:	learn: 0.3345221	total: 18.2s	remaining: 22.2s
# 450:	learn: 0.3344230	total: 18.2s	remaining: 22.2s
# 451:	learn: 0.3343267	total: 18.3s	remaining: 22.1s
# 452:	learn: 0.3342445	total: 18.3s	remaining: 22.1s
# 453:	learn: 0.3341036	total: 18.3s	remaining: 22.1s
# 454:	learn: 0.3339790	total: 18.4s	remaining: 22s
# 455:	learn: 0.3339103	total: 18.4s	remaining: 21.9s
# 456:	learn: 0.3338499	total: 18.4s	remaining: 21.9s
# 457:	learn: 0.3337432	total: 18.5s	remaining: 21.8s
# 458:	learn: 0.3335490	total: 18.5s	remaining: 21.8s
# 459:	learn: 0.3334185	total: 18.5s	remaining: 21.7s
# 460:	learn: 0.3333412	total: 18.6s	remaining: 21.7s
# 461:	learn: 0.3332847	total: 18.6s	remaining: 21.6s
# 462:	learn: 0.3332049	total: 18.6s	remaining: 21.6s
# 463:	learn: 0.3330624	total: 18.7s	remaining: 21.6s
# 464:	learn: 0.3329648	total: 18.7s	remaining: 21.5s
# 465:	learn: 0.3328671	total: 18.7s	remaining: 21.4s
# 466:	learn: 0.3327097	total: 18.8s	remaining: 21.4s
# 467:	learn: 0.3325962	total: 18.8s	remaining: 21.4s
# 468:	learn: 0.3325428	total: 18.8s	remaining: 21.3s
# 469:	learn: 0.3323755	total: 18.9s	remaining: 21.3s
# 470:	learn: 0.3322565	total: 18.9s	remaining: 21.2s
# 471:	learn: 0.3321652	total: 18.9s	remaining: 21.2s
# 472:	learn: 0.3320793	total: 19s	remaining: 21.1s
# 473:	learn: 0.3319987	total: 19s	remaining: 21.1s
# 474:	learn: 0.3319468	total: 19.1s	remaining: 21.1s
# 475:	learn: 0.3318708	total: 19.1s	remaining: 21s
# 476:	learn: 0.3317696	total: 19.1s	remaining: 21s
# 477:	learn: 0.3316895	total: 19.2s	remaining: 20.9s
# 478:	learn: 0.3316260	total: 19.2s	remaining: 20.9s
# 479:	learn: 0.3314995	total: 19.2s	remaining: 20.8s
# 480:	learn: 0.3314348	total: 19.3s	remaining: 20.8s
# 481:	learn: 0.3313255	total: 19.3s	remaining: 20.7s
# 482:	learn: 0.3312505	total: 19.3s	remaining: 20.7s
# 483:	learn: 0.3310792	total: 19.4s	remaining: 20.6s
# 484:	learn: 0.3309958	total: 19.4s	remaining: 20.6s
# 485:	learn: 0.3308980	total: 19.4s	remaining: 20.5s
# 486:	learn: 0.3308181	total: 19.4s	remaining: 20.5s
# 487:	learn: 0.3307005	total: 19.5s	remaining: 20.4s
# 488:	learn: 0.3306356	total: 19.5s	remaining: 20.4s
# 489:	learn: 0.3305079	total: 19.5s	remaining: 20.3s
# 490:	learn: 0.3303044	total: 19.6s	remaining: 20.3s
# 491:	learn: 0.3302202	total: 19.6s	remaining: 20.2s
# 492:	learn: 0.3301374	total: 19.6s	remaining: 20.2s
# 493:	learn: 0.3300771	total: 19.7s	remaining: 20.1s
# 494:	learn: 0.3300037	total: 19.7s	remaining: 20.1s
# 495:	learn: 0.3297505	total: 19.7s	remaining: 20.1s
# 496:	learn: 0.3296477	total: 19.8s	remaining: 20s
# 497:	learn: 0.3294947	total: 19.8s	remaining: 20s
# 498:	learn: 0.3293977	total: 19.8s	remaining: 19.9s
# 499:	learn: 0.3293443	total: 19.9s	remaining: 19.9s
# 500:	learn: 0.3292531	total: 19.9s	remaining: 19.8s
# 501:	learn: 0.3291788	total: 20s	remaining: 19.8s
# 502:	learn: 0.3289599	total: 20s	remaining: 19.7s
# 503:	learn: 0.3288540	total: 20s	remaining: 19.7s
# 504:	learn: 0.3288084	total: 20.1s	remaining: 19.7s
# 505:	learn: 0.3286166	total: 20.1s	remaining: 19.6s
# 506:	learn: 0.3284826	total: 20.1s	remaining: 19.6s
# 507:	learn: 0.3283895	total: 20.2s	remaining: 19.5s
# 508:	learn: 0.3282333	total: 20.2s	remaining: 19.5s
# 509:	learn: 0.3281124	total: 20.2s	remaining: 19.4s
# 510:	learn: 0.3280064	total: 20.2s	remaining: 19.4s
# 511:	learn: 0.3279275	total: 20.3s	remaining: 19.3s
# 512:	learn: 0.3277796	total: 20.3s	remaining: 19.3s
# 513:	learn: 0.3276471	total: 20.4s	remaining: 19.3s
# 514:	learn: 0.3275816	total: 20.4s	remaining: 19.2s
# 515:	learn: 0.3274937	total: 20.4s	remaining: 19.2s
# 516:	learn: 0.3273916	total: 20.5s	remaining: 19.1s
# 517:	learn: 0.3273107	total: 20.5s	remaining: 19.1s
# 518:	learn: 0.3272440	total: 20.5s	remaining: 19s
# 519:	learn: 0.3271170	total: 20.6s	remaining: 19s
# 520:	learn: 0.3270342	total: 20.6s	remaining: 18.9s
# 521:	learn: 0.3269224	total: 20.6s	remaining: 18.9s
# 522:	learn: 0.3268314	total: 20.7s	remaining: 18.8s
# 523:	learn: 0.3267433	total: 20.7s	remaining: 18.8s
# 524:	learn: 0.3266935	total: 20.7s	remaining: 18.7s
# 525:	learn: 0.3266145	total: 20.8s	remaining: 18.7s
# 526:	learn: 0.3265463	total: 20.8s	remaining: 18.7s
# 527:	learn: 0.3264865	total: 20.8s	remaining: 18.6s
# 528:	learn: 0.3263916	total: 20.9s	remaining: 18.6s
# 529:	learn: 0.3263104	total: 20.9s	remaining: 18.5s
# 530:	learn: 0.3262217	total: 20.9s	remaining: 18.5s
# 531:	learn: 0.3261177	total: 21s	remaining: 18.4s
# 532:	learn: 0.3260560	total: 21s	remaining: 18.4s
# 533:	learn: 0.3259072	total: 21.1s	remaining: 18.4s
# 534:	learn: 0.3258337	total: 21.1s	remaining: 18.3s
# 535:	learn: 0.3257461	total: 21.1s	remaining: 18.3s
# 536:	learn: 0.3256686	total: 21.2s	remaining: 18.2s
# 537:	learn: 0.3255659	total: 21.2s	remaining: 18.2s
# 538:	learn: 0.3255127	total: 21.2s	remaining: 18.2s
# 539:	learn: 0.3254159	total: 21.3s	remaining: 18.1s
# 540:	learn: 0.3253402	total: 21.3s	remaining: 18.1s
# 541:	learn: 0.3252831	total: 21.3s	remaining: 18s
# 542:	learn: 0.3251779	total: 21.4s	remaining: 18s
# 543:	learn: 0.3250643	total: 21.4s	remaining: 17.9s
# 544:	learn: 0.3250055	total: 21.4s	remaining: 17.9s
# 545:	learn: 0.3248758	total: 21.5s	remaining: 17.9s
# 546:	learn: 0.3247699	total: 21.5s	remaining: 17.8s
# 547:	learn: 0.3246883	total: 21.6s	remaining: 17.8s
# 548:	learn: 0.3246113	total: 21.6s	remaining: 17.8s
# 549:	learn: 0.3245218	total: 21.7s	remaining: 17.7s
# 550:	learn: 0.3244540	total: 21.8s	remaining: 17.7s
# 551:	learn: 0.3243479	total: 21.8s	remaining: 17.7s
# 552:	learn: 0.3241727	total: 21.9s	remaining: 17.7s
# 553:	learn: 0.3240674	total: 21.9s	remaining: 17.7s
# 554:	learn: 0.3240153	total: 22s	remaining: 17.7s
# 555:	learn: 0.3239591	total: 22.1s	remaining: 17.6s
# 556:	learn: 0.3239004	total: 22.2s	remaining: 17.6s
# 557:	learn: 0.3238473	total: 22.3s	remaining: 17.6s
# 558:	learn: 0.3237310	total: 22.3s	remaining: 17.6s
# 559:	learn: 0.3236698	total: 22.4s	remaining: 17.6s
# 560:	learn: 0.3236092	total: 22.5s	remaining: 17.6s
# 561:	learn: 0.3235428	total: 22.6s	remaining: 17.6s
# 562:	learn: 0.3234821	total: 22.6s	remaining: 17.6s
# 563:	learn: 0.3234245	total: 22.7s	remaining: 17.6s
# 564:	learn: 0.3233739	total: 22.8s	remaining: 17.5s
# 565:	learn: 0.3233134	total: 22.9s	remaining: 17.5s
# 566:	learn: 0.3232055	total: 22.9s	remaining: 17.5s
# 567:	learn: 0.3230861	total: 23s	remaining: 17.5s
# 568:	learn: 0.3229779	total: 23.1s	remaining: 17.5s
# 569:	learn: 0.3228978	total: 23.1s	remaining: 17.5s
# 570:	learn: 0.3228551	total: 23.2s	remaining: 17.4s
# 571:	learn: 0.3227798	total: 23.3s	remaining: 17.4s
# 572:	learn: 0.3226801	total: 23.4s	remaining: 17.4s
# 573:	learn: 0.3226201	total: 23.4s	remaining: 17.4s
# 574:	learn: 0.3225669	total: 23.5s	remaining: 17.3s
# 575:	learn: 0.3225007	total: 23.5s	remaining: 17.3s
# 576:	learn: 0.3224076	total: 23.6s	remaining: 17.3s
# 577:	learn: 0.3223135	total: 23.7s	remaining: 17.3s
# 578:	learn: 0.3222218	total: 23.8s	remaining: 17.3s
# 579:	learn: 0.3221446	total: 23.9s	remaining: 17.3s
# 580:	learn: 0.3220734	total: 23.9s	remaining: 17.3s
# 581:	learn: 0.3219988	total: 24s	remaining: 17.3s
# 582:	learn: 0.3219175	total: 24.1s	remaining: 17.2s
# 583:	learn: 0.3218690	total: 24.2s	remaining: 17.2s
# 584:	learn: 0.3218233	total: 24.2s	remaining: 17.2s
# 585:	learn: 0.3217346	total: 24.3s	remaining: 17.2s
# 586:	learn: 0.3216335	total: 24.4s	remaining: 17.2s
# 587:	learn: 0.3215217	total: 24.5s	remaining: 17.2s
# 588:	learn: 0.3214072	total: 24.6s	remaining: 17.1s
# 589:	learn: 0.3213387	total: 24.6s	remaining: 17.1s
# 590:	learn: 0.3212569	total: 24.7s	remaining: 17.1s
# 591:	learn: 0.3212146	total: 24.8s	remaining: 17.1s
# 592:	learn: 0.3211253	total: 24.9s	remaining: 17.1s
# 593:	learn: 0.3210725	total: 24.9s	remaining: 17s
# 594:	learn: 0.3210080	total: 25s	remaining: 17s
# 595:	learn: 0.3209241	total: 25.1s	remaining: 17s
# 596:	learn: 0.3208329	total: 25.2s	remaining: 17s
# 597:	learn: 0.3207434	total: 25.2s	remaining: 17s
# 598:	learn: 0.3206151	total: 25.3s	remaining: 16.9s
# 599:	learn: 0.3205178	total: 25.4s	remaining: 16.9s
# 600:	learn: 0.3204427	total: 25.5s	remaining: 16.9s
# 601:	learn: 0.3203985	total: 25.5s	remaining: 16.9s
# 602:	learn: 0.3202332	total: 25.6s	remaining: 16.9s
# 603:	learn: 0.3201047	total: 25.7s	remaining: 16.9s
# 604:	learn: 0.3200125	total: 25.8s	remaining: 16.8s
# 605:	learn: 0.3199545	total: 25.8s	remaining: 16.8s
# 606:	learn: 0.3198640	total: 25.9s	remaining: 16.8s
# 607:	learn: 0.3198050	total: 26s	remaining: 16.7s
# 608:	learn: 0.3197451	total: 26.1s	remaining: 16.7s
# 609:	learn: 0.3196963	total: 26.1s	remaining: 16.7s
# 610:	learn: 0.3196405	total: 26.2s	remaining: 16.7s
# 611:	learn: 0.3195814	total: 26.3s	remaining: 16.7s
# 612:	learn: 0.3195389	total: 26.4s	remaining: 16.7s
# 613:	learn: 0.3194626	total: 26.5s	remaining: 16.6s
# 614:	learn: 0.3194196	total: 26.5s	remaining: 16.6s
# 615:	learn: 0.3193507	total: 26.6s	remaining: 16.6s
# 616:	learn: 0.3192722	total: 26.7s	remaining: 16.6s
# 617:	learn: 0.3191942	total: 26.8s	remaining: 16.5s
# 618:	learn: 0.3190973	total: 26.8s	remaining: 16.5s
# 619:	learn: 0.3189672	total: 26.9s	remaining: 16.5s
# 620:	learn: 0.3188937	total: 27s	remaining: 16.5s
# 621:	learn: 0.3187926	total: 27.1s	remaining: 16.5s
# 622:	learn: 0.3186488	total: 27.1s	remaining: 16.4s
# 623:	learn: 0.3185692	total: 27.2s	remaining: 16.4s
# 624:	learn: 0.3184767	total: 27.2s	remaining: 16.3s
# 625:	learn: 0.3183849	total: 27.2s	remaining: 16.3s
# 626:	learn: 0.3181994	total: 27.3s	remaining: 16.2s
# 627:	learn: 0.3180916	total: 27.3s	remaining: 16.2s
# 628:	learn: 0.3180018	total: 27.3s	remaining: 16.1s
# 629:	learn: 0.3179570	total: 27.4s	remaining: 16.1s
# 630:	learn: 0.3178615	total: 27.4s	remaining: 16s
# 631:	learn: 0.3177483	total: 27.4s	remaining: 16s
# 632:	learn: 0.3176606	total: 27.5s	remaining: 15.9s
# 633:	learn: 0.3176009	total: 27.5s	remaining: 15.9s
# 634:	learn: 0.3175224	total: 27.5s	remaining: 15.8s
# 635:	learn: 0.3174339	total: 27.6s	remaining: 15.8s
# 636:	learn: 0.3173814	total: 27.6s	remaining: 15.7s
# 637:	learn: 0.3172266	total: 27.6s	remaining: 15.7s
# 638:	learn: 0.3171587	total: 27.7s	remaining: 15.6s
# 639:	learn: 0.3170759	total: 27.7s	remaining: 15.6s
# 640:	learn: 0.3170261	total: 27.7s	remaining: 15.5s
# 641:	learn: 0.3169792	total: 27.8s	remaining: 15.5s
# 642:	learn: 0.3169121	total: 27.8s	remaining: 15.4s
# 643:	learn: 0.3168040	total: 27.8s	remaining: 15.4s
# 644:	learn: 0.3167373	total: 27.9s	remaining: 15.3s
# 645:	learn: 0.3166764	total: 27.9s	remaining: 15.3s
# 646:	learn: 0.3166013	total: 28s	remaining: 15.3s
# 647:	learn: 0.3165395	total: 28s	remaining: 15.2s
# 648:	learn: 0.3164843	total: 28s	remaining: 15.1s
# 649:	learn: 0.3164458	total: 28s	remaining: 15.1s
# 650:	learn: 0.3163708	total: 28.1s	remaining: 15.1s
# 651:	learn: 0.3162347	total: 28.1s	remaining: 15s
# 652:	learn: 0.3161565	total: 28.1s	remaining: 15s
# 653:	learn: 0.3160783	total: 28.2s	remaining: 14.9s
# 654:	learn: 0.3159471	total: 28.2s	remaining: 14.9s
# 655:	learn: 0.3158686	total: 28.3s	remaining: 14.8s
# 656:	learn: 0.3158021	total: 28.3s	remaining: 14.8s
# 657:	learn: 0.3157258	total: 28.3s	remaining: 14.7s
# 658:	learn: 0.3156553	total: 28.4s	remaining: 14.7s
# 659:	learn: 0.3155476	total: 28.4s	remaining: 14.6s
# 660:	learn: 0.3154868	total: 28.4s	remaining: 14.6s
# 661:	learn: 0.3153990	total: 28.5s	remaining: 14.5s
# 662:	learn: 0.3153591	total: 28.5s	remaining: 14.5s
# 663:	learn: 0.3153015	total: 28.5s	remaining: 14.4s
# 664:	learn: 0.3152574	total: 28.6s	remaining: 14.4s
# 665:	learn: 0.3152070	total: 28.6s	remaining: 14.3s
# 666:	learn: 0.3151741	total: 28.6s	remaining: 14.3s
# 667:	learn: 0.3150998	total: 28.6s	remaining: 14.2s
# 668:	learn: 0.3149626	total: 28.7s	remaining: 14.2s
# 669:	learn: 0.3148751	total: 28.7s	remaining: 14.1s
# 670:	learn: 0.3147756	total: 28.7s	remaining: 14.1s
# 671:	learn: 0.3147197	total: 28.8s	remaining: 14s
# 672:	learn: 0.3146114	total: 28.8s	remaining: 14s
# 673:	learn: 0.3145164	total: 28.8s	remaining: 14s
# 674:	learn: 0.3144409	total: 28.9s	remaining: 13.9s
# 675:	learn: 0.3143799	total: 28.9s	remaining: 13.9s
# 676:	learn: 0.3142967	total: 29s	remaining: 13.8s
# 677:	learn: 0.3142048	total: 29s	remaining: 13.8s
# 678:	learn: 0.3141284	total: 29s	remaining: 13.7s
# 679:	learn: 0.3140518	total: 29s	remaining: 13.7s
# 680:	learn: 0.3139750	total: 29.1s	remaining: 13.6s
# 681:	learn: 0.3139483	total: 29.1s	remaining: 13.6s
# 682:	learn: 0.3138784	total: 29.1s	remaining: 13.5s
# 683:	learn: 0.3138393	total: 29.2s	remaining: 13.5s
# 684:	learn: 0.3137897	total: 29.2s	remaining: 13.4s
# 685:	learn: 0.3136853	total: 29.3s	remaining: 13.4s
# 686:	learn: 0.3135827	total: 29.3s	remaining: 13.3s
# 687:	learn: 0.3135329	total: 29.3s	remaining: 13.3s
# 688:	learn: 0.3134703	total: 29.4s	remaining: 13.3s
# 689:	learn: 0.3134154	total: 29.4s	remaining: 13.2s
# 690:	learn: 0.3133562	total: 29.4s	remaining: 13.2s
# 691:	learn: 0.3132690	total: 29.4s	remaining: 13.1s
# 692:	learn: 0.3131162	total: 29.5s	remaining: 13.1s
# 693:	learn: 0.3130386	total: 29.5s	remaining: 13s
# 694:	learn: 0.3129591	total: 29.6s	remaining: 13s
# 695:	learn: 0.3128918	total: 29.6s	remaining: 12.9s
# 696:	learn: 0.3127935	total: 29.6s	remaining: 12.9s
# 697:	learn: 0.3127359	total: 29.7s	remaining: 12.8s
# 698:	learn: 0.3126557	total: 29.7s	remaining: 12.8s
# 699:	learn: 0.3125450	total: 29.7s	remaining: 12.7s
# 700:	learn: 0.3123776	total: 29.8s	remaining: 12.7s
# 701:	learn: 0.3123009	total: 29.8s	remaining: 12.6s
# 702:	learn: 0.3122447	total: 29.8s	remaining: 12.6s
# 703:	learn: 0.3121679	total: 29.9s	remaining: 12.6s
# 704:	learn: 0.3121188	total: 29.9s	remaining: 12.5s
# 705:	learn: 0.3119881	total: 29.9s	remaining: 12.5s
# 706:	learn: 0.3118911	total: 30s	remaining: 12.4s
# 707:	learn: 0.3118398	total: 30s	remaining: 12.4s
# 708:	learn: 0.3117323	total: 30s	remaining: 12.3s
# 709:	learn: 0.3116523	total: 30.1s	remaining: 12.3s
# 710:	learn: 0.3115705	total: 30.1s	remaining: 12.2s
# 711:	learn: 0.3115052	total: 30.1s	remaining: 12.2s
# 712:	learn: 0.3114361	total: 30.2s	remaining: 12.1s
# 713:	learn: 0.3113918	total: 30.2s	remaining: 12.1s
# 714:	learn: 0.3113077	total: 30.2s	remaining: 12s
# 715:	learn: 0.3112630	total: 30.3s	remaining: 12s
# 716:	learn: 0.3112022	total: 30.3s	remaining: 12s
# 717:	learn: 0.3111165	total: 30.3s	remaining: 11.9s
# 718:	learn: 0.3110538	total: 30.4s	remaining: 11.9s
# 719:	learn: 0.3109397	total: 30.4s	remaining: 11.8s
# 720:	learn: 0.3108877	total: 30.4s	remaining: 11.8s
# 721:	learn: 0.3107977	total: 30.5s	remaining: 11.7s
# 722:	learn: 0.3107178	total: 30.5s	remaining: 11.7s
# 723:	learn: 0.3106234	total: 30.5s	remaining: 11.6s
# 724:	learn: 0.3105343	total: 30.6s	remaining: 11.6s
# 725:	learn: 0.3104607	total: 30.6s	remaining: 11.5s
# 726:	learn: 0.3103972	total: 30.6s	remaining: 11.5s
# 727:	learn: 0.3103546	total: 30.7s	remaining: 11.5s
# 728:	learn: 0.3102273	total: 30.7s	remaining: 11.4s
# 729:	learn: 0.3101530	total: 30.7s	remaining: 11.4s
# 730:	learn: 0.3100704	total: 30.8s	remaining: 11.3s
# 731:	learn: 0.3099756	total: 30.8s	remaining: 11.3s
# 732:	learn: 0.3099111	total: 30.8s	remaining: 11.2s
# 733:	learn: 0.3098581	total: 30.9s	remaining: 11.2s
# 734:	learn: 0.3097210	total: 30.9s	remaining: 11.1s
# 735:	learn: 0.3096773	total: 30.9s	remaining: 11.1s
# 736:	learn: 0.3096063	total: 31s	remaining: 11s
# 737:	learn: 0.3095485	total: 31s	remaining: 11s
# 738:	learn: 0.3094775	total: 31s	remaining: 11s
# 739:	learn: 0.3094086	total: 31.1s	remaining: 10.9s
# 740:	learn: 0.3093132	total: 31.1s	remaining: 10.9s
# 741:	learn: 0.3091476	total: 31.1s	remaining: 10.8s
# 742:	learn: 0.3090359	total: 31.1s	remaining: 10.8s
# 743:	learn: 0.3089329	total: 31.2s	remaining: 10.7s
# 744:	learn: 0.3088314	total: 31.2s	remaining: 10.7s
# 745:	learn: 0.3087011	total: 31.2s	remaining: 10.6s
# 746:	learn: 0.3086222	total: 31.3s	remaining: 10.6s
# 747:	learn: 0.3085407	total: 31.3s	remaining: 10.6s
# 748:	learn: 0.3084510	total: 31.4s	remaining: 10.5s
# 749:	learn: 0.3083743	total: 31.4s	remaining: 10.5s
# 750:	learn: 0.3082586	total: 31.4s	remaining: 10.4s
# 751:	learn: 0.3082002	total: 31.5s	remaining: 10.4s
# 752:	learn: 0.3081390	total: 31.5s	remaining: 10.3s
# 753:	learn: 0.3080135	total: 31.5s	remaining: 10.3s
# 754:	learn: 0.3079352	total: 31.6s	remaining: 10.2s
# 755:	learn: 0.3078969	total: 31.6s	remaining: 10.2s
# 756:	learn: 0.3078379	total: 31.6s	remaining: 10.2s
# 757:	learn: 0.3077922	total: 31.7s	remaining: 10.1s
# 758:	learn: 0.3077287	total: 31.7s	remaining: 10.1s
# 759:	learn: 0.3076875	total: 31.7s	remaining: 10s
# 760:	learn: 0.3076007	total: 31.8s	remaining: 9.98s
# 761:	learn: 0.3074890	total: 31.8s	remaining: 9.93s
# 762:	learn: 0.3074275	total: 31.8s	remaining: 9.89s
# 763:	learn: 0.3073089	total: 31.9s	remaining: 9.85s
# 764:	learn: 0.3072337	total: 31.9s	remaining: 9.8s
# 765:	learn: 0.3071952	total: 31.9s	remaining: 9.76s
# 766:	learn: 0.3071474	total: 32s	remaining: 9.71s
# 767:	learn: 0.3070743	total: 32s	remaining: 9.67s
# 768:	learn: 0.3069886	total: 32s	remaining: 9.63s
# 769:	learn: 0.3068962	total: 32.1s	remaining: 9.58s
# 770:	learn: 0.3068303	total: 32.1s	remaining: 9.54s
# 771:	learn: 0.3067882	total: 32.1s	remaining: 9.49s
# 772:	learn: 0.3067144	total: 32.2s	remaining: 9.45s
# 773:	learn: 0.3066434	total: 32.2s	remaining: 9.4s
# 774:	learn: 0.3065831	total: 32.2s	remaining: 9.36s
# 775:	learn: 0.3065311	total: 32.3s	remaining: 9.32s
# 776:	learn: 0.3064537	total: 32.3s	remaining: 9.28s
# 777:	learn: 0.3063375	total: 32.4s	remaining: 9.24s
# 778:	learn: 0.3062691	total: 32.4s	remaining: 9.19s
# 779:	learn: 0.3061950	total: 32.4s	remaining: 9.15s
# 780:	learn: 0.3061049	total: 32.5s	remaining: 9.1s
# 781:	learn: 0.3060128	total: 32.5s	remaining: 9.06s
# 782:	learn: 0.3059634	total: 32.5s	remaining: 9.02s
# 783:	learn: 0.3058881	total: 32.6s	remaining: 8.97s
# 784:	learn: 0.3058152	total: 32.6s	remaining: 8.93s
# 785:	learn: 0.3057454	total: 32.6s	remaining: 8.88s
# 786:	learn: 0.3056762	total: 32.7s	remaining: 8.84s
# 787:	learn: 0.3055877	total: 32.7s	remaining: 8.8s
# 788:	learn: 0.3055189	total: 32.7s	remaining: 8.75s
# 789:	learn: 0.3054392	total: 32.8s	remaining: 8.71s
# 790:	learn: 0.3053351	total: 32.8s	remaining: 8.66s
# 791:	learn: 0.3052252	total: 32.8s	remaining: 8.62s
# 792:	learn: 0.3051485	total: 32.9s	remaining: 8.58s
# 793:	learn: 0.3050567	total: 32.9s	remaining: 8.53s
# 794:	learn: 0.3050080	total: 32.9s	remaining: 8.49s
# 795:	learn: 0.3049528	total: 33s	remaining: 8.45s
# 796:	learn: 0.3048648	total: 33s	remaining: 8.4s
# 797:	learn: 0.3047927	total: 33s	remaining: 8.36s
# 798:	learn: 0.3047247	total: 33.1s	remaining: 8.32s
# 799:	learn: 0.3046588	total: 33.1s	remaining: 8.27s
# 800:	learn: 0.3046012	total: 33.1s	remaining: 8.23s
# 801:	learn: 0.3045528	total: 33.2s	remaining: 8.19s
# 802:	learn: 0.3045030	total: 33.2s	remaining: 8.14s
# 803:	learn: 0.3044360	total: 33.2s	remaining: 8.1s
# 804:	learn: 0.3043736	total: 33.3s	remaining: 8.06s
# 805:	learn: 0.3043048	total: 33.3s	remaining: 8.01s
# 806:	learn: 0.3042442	total: 33.3s	remaining: 7.97s
# 807:	learn: 0.3042070	total: 33.4s	remaining: 7.93s
# 808:	learn: 0.3041623	total: 33.4s	remaining: 7.89s
# 809:	learn: 0.3041143	total: 33.4s	remaining: 7.84s
# 810:	learn: 0.3040668	total: 33.5s	remaining: 7.8s
# 811:	learn: 0.3040164	total: 33.5s	remaining: 7.76s
# 812:	learn: 0.3039356	total: 33.5s	remaining: 7.71s
# 813:	learn: 0.3038593	total: 33.6s	remaining: 7.67s
# 814:	learn: 0.3037953	total: 33.6s	remaining: 7.63s
# 815:	learn: 0.3037107	total: 33.6s	remaining: 7.58s
# 816:	learn: 0.3036811	total: 33.7s	remaining: 7.54s
# 817:	learn: 0.3036132	total: 33.7s	remaining: 7.5s
# 818:	learn: 0.3035251	total: 33.7s	remaining: 7.46s
# 819:	learn: 0.3034655	total: 33.8s	remaining: 7.41s
# 820:	learn: 0.3033849	total: 33.8s	remaining: 7.37s
# 821:	learn: 0.3033139	total: 33.9s	remaining: 7.33s
# 822:	learn: 0.3032120	total: 33.9s	remaining: 7.29s
# 823:	learn: 0.3031398	total: 33.9s	remaining: 7.25s
# 824:	learn: 0.3030420	total: 34s	remaining: 7.2s
# 825:	learn: 0.3029602	total: 34s	remaining: 7.16s
# 826:	learn: 0.3028735	total: 34s	remaining: 7.12s
# 827:	learn: 0.3028214	total: 34.1s	remaining: 7.07s
# 828:	learn: 0.3027555	total: 34.1s	remaining: 7.03s
# 829:	learn: 0.3027097	total: 34.1s	remaining: 6.99s
# 830:	learn: 0.3025874	total: 34.2s	remaining: 6.95s
# 831:	learn: 0.3025460	total: 34.2s	remaining: 6.9s
# 832:	learn: 0.3024772	total: 34.2s	remaining: 6.86s
# 833:	learn: 0.3024099	total: 34.3s	remaining: 6.82s
# 834:	learn: 0.3023645	total: 34.3s	remaining: 6.78s
# 835:	learn: 0.3023333	total: 34.3s	remaining: 6.73s
# 836:	learn: 0.3022955	total: 34.4s	remaining: 6.69s
# 837:	learn: 0.3022632	total: 34.4s	remaining: 6.65s
# 838:	learn: 0.3021734	total: 34.4s	remaining: 6.61s
# 839:	learn: 0.3021490	total: 34.5s	remaining: 6.57s
# 840:	learn: 0.3021004	total: 34.5s	remaining: 6.52s
# 841:	learn: 0.3020134	total: 34.5s	remaining: 6.48s
# 842:	learn: 0.3019491	total: 34.6s	remaining: 6.44s
# 843:	learn: 0.3019044	total: 34.6s	remaining: 6.4s
# 844:	learn: 0.3018158	total: 34.6s	remaining: 6.35s
# 845:	learn: 0.3017684	total: 34.7s	remaining: 6.31s
# 846:	learn: 0.3017261	total: 34.7s	remaining: 6.27s
# 847:	learn: 0.3016584	total: 34.7s	remaining: 6.23s
# 848:	learn: 0.3016195	total: 34.8s	remaining: 6.18s
# 849:	learn: 0.3015201	total: 34.8s	remaining: 6.14s
# 850:	learn: 0.3014337	total: 34.9s	remaining: 6.1s
# 851:	learn: 0.3013993	total: 34.9s	remaining: 6.06s
# 852:	learn: 0.3013410	total: 34.9s	remaining: 6.02s
# 853:	learn: 0.3012885	total: 34.9s	remaining: 5.97s
# 854:	learn: 0.3012142	total: 35s	remaining: 5.93s
# 855:	learn: 0.3011380	total: 35s	remaining: 5.89s
# 856:	learn: 0.3010938	total: 35s	remaining: 5.85s
# 857:	learn: 0.3010346	total: 35.1s	remaining: 5.81s
# 858:	learn: 0.3009792	total: 35.1s	remaining: 5.76s
# 859:	learn: 0.3009373	total: 35.1s	remaining: 5.72s
# 860:	learn: 0.3008282	total: 35.2s	remaining: 5.68s
# 861:	learn: 0.3007686	total: 35.2s	remaining: 5.64s
# 862:	learn: 0.3006929	total: 35.2s	remaining: 5.59s
# 863:	learn: 0.3006340	total: 35.3s	remaining: 5.55s
# 864:	learn: 0.3005225	total: 35.3s	remaining: 5.51s
# 865:	learn: 0.3004695	total: 35.3s	remaining: 5.47s
# 866:	learn: 0.3004220	total: 35.4s	remaining: 5.43s
# 867:	learn: 0.3003064	total: 35.4s	remaining: 5.39s
# 868:	learn: 0.3002311	total: 35.5s	remaining: 5.35s
# 869:	learn: 0.3001284	total: 35.5s	remaining: 5.3s
# 870:	learn: 0.3000496	total: 35.5s	remaining: 5.26s
# 871:	learn: 0.3000010	total: 35.6s	remaining: 5.22s
# 872:	learn: 0.2998876	total: 35.6s	remaining: 5.18s
# 873:	learn: 0.2998358	total: 35.6s	remaining: 5.14s
# 874:	learn: 0.2997822	total: 35.7s	remaining: 5.09s
# 875:	learn: 0.2997552	total: 35.7s	remaining: 5.05s
# 876:	learn: 0.2997184	total: 35.7s	remaining: 5.01s
# 877:	learn: 0.2996232	total: 35.8s	remaining: 4.97s
# 878:	learn: 0.2994633	total: 35.8s	remaining: 4.93s
# 879:	learn: 0.2993465	total: 35.8s	remaining: 4.88s
# 880:	learn: 0.2992900	total: 35.9s	remaining: 4.84s
# 881:	learn: 0.2992313	total: 35.9s	remaining: 4.8s
# 882:	learn: 0.2991520	total: 35.9s	remaining: 4.76s
# 883:	learn: 0.2990382	total: 36s	remaining: 4.72s
# 884:	learn: 0.2989881	total: 36s	remaining: 4.68s
# 885:	learn: 0.2989086	total: 36s	remaining: 4.64s
# 886:	learn: 0.2988541	total: 36.1s	remaining: 4.59s
# 887:	learn: 0.2987274	total: 36.1s	remaining: 4.55s
# 888:	learn: 0.2986381	total: 36.1s	remaining: 4.51s
# 889:	learn: 0.2985734	total: 36.2s	remaining: 4.47s
# 890:	learn: 0.2985215	total: 36.2s	remaining: 4.43s
# 891:	learn: 0.2984644	total: 36.2s	remaining: 4.39s
# 892:	learn: 0.2984126	total: 36.3s	remaining: 4.34s
# 893:	learn: 0.2983713	total: 36.3s	remaining: 4.3s
# 894:	learn: 0.2983422	total: 36.3s	remaining: 4.26s
# 895:	learn: 0.2983197	total: 36.4s	remaining: 4.22s
# 896:	learn: 0.2982604	total: 36.4s	remaining: 4.18s
# 897:	learn: 0.2982101	total: 36.5s	remaining: 4.14s
# 898:	learn: 0.2981529	total: 36.5s	remaining: 4.1s
# 899:	learn: 0.2980693	total: 36.5s	remaining: 4.06s
# 900:	learn: 0.2980146	total: 36.5s	remaining: 4.01s
# 901:	learn: 0.2979654	total: 36.6s	remaining: 3.97s
# 902:	learn: 0.2978673	total: 36.6s	remaining: 3.93s
# 903:	learn: 0.2978123	total: 36.6s	remaining: 3.89s
# 904:	learn: 0.2977661	total: 36.7s	remaining: 3.85s
# 905:	learn: 0.2976818	total: 36.7s	remaining: 3.81s
# 906:	learn: 0.2976306	total: 36.7s	remaining: 3.77s
# 907:	learn: 0.2975318	total: 36.8s	remaining: 3.73s
# 908:	learn: 0.2974881	total: 36.8s	remaining: 3.69s
# 909:	learn: 0.2974460	total: 36.9s	remaining: 3.64s
# 910:	learn: 0.2973879	total: 36.9s	remaining: 3.6s
# 911:	learn: 0.2973331	total: 36.9s	remaining: 3.56s
# 912:	learn: 0.2972367	total: 36.9s	remaining: 3.52s
# 913:	learn: 0.2971929	total: 37s	remaining: 3.48s
# 914:	learn: 0.2971542	total: 37s	remaining: 3.44s
# 915:	learn: 0.2970877	total: 37.1s	remaining: 3.4s
# 916:	learn: 0.2970504	total: 37.2s	remaining: 3.37s
# 917:	learn: 0.2969582	total: 37.3s	remaining: 3.33s
# 918:	learn: 0.2968830	total: 37.3s	remaining: 3.29s
# 919:	learn: 0.2968161	total: 37.4s	remaining: 3.25s
# 920:	learn: 0.2967801	total: 37.5s	remaining: 3.22s
# 921:	learn: 0.2967408	total: 37.6s	remaining: 3.18s
# 922:	learn: 0.2967106	total: 37.7s	remaining: 3.14s
# 923:	learn: 0.2966607	total: 37.7s	remaining: 3.1s
# 924:	learn: 0.2965978	total: 37.8s	remaining: 3.07s
# 925:	learn: 0.2965667	total: 37.9s	remaining: 3.03s
# 926:	learn: 0.2965098	total: 38s	remaining: 2.99s
# 927:	learn: 0.2964024	total: 38.1s	remaining: 2.95s
# 928:	learn: 0.2963441	total: 38.1s	remaining: 2.92s
# 929:	learn: 0.2962585	total: 38.2s	remaining: 2.88s
# 930:	learn: 0.2961973	total: 38.3s	remaining: 2.84s
# 931:	learn: 0.2961335	total: 38.4s	remaining: 2.8s
# 932:	learn: 0.2960714	total: 38.5s	remaining: 2.76s
# 933:	learn: 0.2960375	total: 38.5s	remaining: 2.72s
# 934:	learn: 0.2959978	total: 38.6s	remaining: 2.68s
# 935:	learn: 0.2959342	total: 38.7s	remaining: 2.65s
# 936:	learn: 0.2958929	total: 38.8s	remaining: 2.61s
# 937:	learn: 0.2958401	total: 38.8s	remaining: 2.57s
# 938:	learn: 0.2957996	total: 38.9s	remaining: 2.53s
# 939:	learn: 0.2957284	total: 39s	remaining: 2.49s
# 940:	learn: 0.2956799	total: 39.1s	remaining: 2.45s
# 941:	learn: 0.2956082	total: 39.2s	remaining: 2.41s
# 942:	learn: 0.2955359	total: 39.2s	remaining: 2.37s
# 943:	learn: 0.2954988	total: 39.3s	remaining: 2.33s
# 944:	learn: 0.2954254	total: 39.4s	remaining: 2.29s
# 945:	learn: 0.2953939	total: 39.4s	remaining: 2.25s
# 946:	learn: 0.2953570	total: 39.5s	remaining: 2.21s
# 947:	learn: 0.2952711	total: 39.6s	remaining: 2.17s
# 948:	learn: 0.2951542	total: 39.7s	remaining: 2.13s
# 949:	learn: 0.2950638	total: 39.7s	remaining: 2.09s
# 950:	learn: 0.2950025	total: 39.8s	remaining: 2.05s
# 951:	learn: 0.2949650	total: 39.9s	remaining: 2.01s
# 952:	learn: 0.2948961	total: 40s	remaining: 1.97s
# 953:	learn: 0.2948276	total: 40s	remaining: 1.93s
# 954:	learn: 0.2947860	total: 40.1s	remaining: 1.89s
# 955:	learn: 0.2947313	total: 40.2s	remaining: 1.85s
# 956:	learn: 0.2946415	total: 40.3s	remaining: 1.81s
# 957:	learn: 0.2945984	total: 40.4s	remaining: 1.77s
# 958:	learn: 0.2945460	total: 40.4s	remaining: 1.73s
# 959:	learn: 0.2944979	total: 40.5s	remaining: 1.69s
# 960:	learn: 0.2944446	total: 40.6s	remaining: 1.65s
# 961:	learn: 0.2943810	total: 40.7s	remaining: 1.61s
# 962:	learn: 0.2943267	total: 40.7s	remaining: 1.56s
# 963:	learn: 0.2943097	total: 40.8s	remaining: 1.52s
# 964:	learn: 0.2942772	total: 40.9s	remaining: 1.48s
# 965:	learn: 0.2942291	total: 41s	remaining: 1.44s
# 966:	learn: 0.2941602	total: 41.1s	remaining: 1.4s
# 967:	learn: 0.2941046	total: 41.1s	remaining: 1.36s
# 968:	learn: 0.2940430	total: 41.2s	remaining: 1.32s
# 969:	learn: 0.2939927	total: 41.3s	remaining: 1.28s
# 970:	learn: 0.2939323	total: 41.4s	remaining: 1.23s
# 971:	learn: 0.2938946	total: 41.4s	remaining: 1.19s
# 972:	learn: 0.2938448	total: 41.5s	remaining: 1.15s
# 973:	learn: 0.2937949	total: 41.6s	remaining: 1.11s
# 974:	learn: 0.2937548	total: 41.7s	remaining: 1.07s
# 975:	learn: 0.2936931	total: 41.8s	remaining: 1.03s
# 976:	learn: 0.2936530	total: 41.8s	remaining: 985ms
# 977:	learn: 0.2935776	total: 41.9s	remaining: 943ms
# 978:	learn: 0.2935354	total: 42s	remaining: 901ms
# 979:	learn: 0.2934500	total: 42.1s	remaining: 858ms
# 980:	learn: 0.2933892	total: 42.1s	remaining: 816ms
# 981:	learn: 0.2933028	total: 42.2s	remaining: 774ms
# 982:	learn: 0.2932415	total: 42.3s	remaining: 731ms
# 983:	learn: 0.2931726	total: 42.3s	remaining: 688ms
# 984:	learn: 0.2931027	total: 42.4s	remaining: 645ms
# 985:	learn: 0.2929821	total: 42.4s	remaining: 602ms
# 986:	learn: 0.2929059	total: 42.4s	remaining: 559ms
# 987:	learn: 0.2928305	total: 42.5s	remaining: 516ms
# 988:	learn: 0.2927479	total: 42.5s	remaining: 473ms
# 989:	learn: 0.2926940	total: 42.5s	remaining: 430ms
# 990:	learn: 0.2926430	total: 42.6s	remaining: 387ms
# 991:	learn: 0.2925942	total: 42.6s	remaining: 344ms
# 992:	learn: 0.2925305	total: 42.6s	remaining: 301ms
# 993:	learn: 0.2924574	total: 42.7s	remaining: 258ms
# 994:	learn: 0.2923830	total: 42.7s	remaining: 215ms
# 995:	learn: 0.2923114	total: 42.8s	remaining: 172ms
# 996:	learn: 0.2922751	total: 42.8s	remaining: 129ms
# 997:	learn: 0.2922139	total: 42.8s	remaining: 85.9ms
# 998:	learn: 0.2921432	total: 42.9s	remaining: 42.9ms
# 999:	learn: 0.2920234	total: 42.9s	remaining: 0us
# Model: <catboost.core.CatBoostClassifier object at 0x7cdb9dac33a0>
# Training: 0.8808398559163665
# Validation: 0.8947721179624665
#
# [LightGBM] [Info] Number of positive: 73859, number of negative: 73833
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003276 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 328
# [LightGBM] [Info] Number of data points in the train set: 147692, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500088 -> initscore=0.000352
# [LightGBM] [Info] Start training from score 0.000352
# Model: LGBMClassifier()
# Training: 0.8497887495598949
# Validation: 0.8626005361930295

# %% [markdown]
# For binary prediction the score of each model is not very high. Therefore I am using roc_auc_scores.

# %% [markdown]
# **Using roc_auc:**

# %%
from sklearn.metrics import roc_auc_score
# Defining the models to be evaluated
model_list2 = [LogisticRegression(), DecisionTreeClassifier(), XGBClassifier(), HistGradientBoostingClassifier(), CatBoostClassifier(), lgb.LGBMClassifier(n_estimators=100)]

# Iterating over each model to train and evaluate
for model in model_list2:
    # Fit the model on the training data
    model.fit(X_train, Y_train)

    # Printing model details and evaluation metrics
    print(f'Model: {model}')
    train_predictions = model.predict_proba(X_train)[:, 1]
    val_predictions = model.predict_proba(X_val)[:, 1]
    print('Training:', roc_auc_score(Y_train, train_predictions))
    print('Validation:', roc_auc_score(Y_val, val_predictions))
    print()
# Out:
# Model: LogisticRegression()
# Training: 0.5695351545651138
# Validation: 0.5605979721289052
#
# Model: DecisionTreeClassifier()
# Training: 0.9999996602014816
# Validation: 0.9664031620553359
#
# Model: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# Training: 0.951692506043518
# Validation: 0.9489131782862136
#
# Model: HistGradientBoostingClassifier()
# Training: 0.922049277600572
# Validation: 0.9234165008528851
#
# Learning rate set to 0.086946
# 0:	learn: 0.6427706	total: 35.1ms	remaining: 35.1s
# 1:	learn: 0.6022555	total: 65.3ms	remaining: 32.6s
# 2:	learn: 0.5738600	total: 95.3ms	remaining: 31.7s
# 3:	learn: 0.5506539	total: 130ms	remaining: 32.5s
# 4:	learn: 0.5195984	total: 160ms	remaining: 31.9s
# 5:	learn: 0.5087864	total: 191ms	remaining: 31.7s
# 6:	learn: 0.5001758	total: 221ms	remaining: 31.4s
# 7:	learn: 0.4940132	total: 258ms	remaining: 32s
# 8:	learn: 0.4882223	total: 288ms	remaining: 31.8s
# 9:	learn: 0.4790298	total: 323ms	remaining: 32s
# 10:	learn: 0.4729998	total: 358ms	remaining: 32.2s
# 11:	learn: 0.4698226	total: 388ms	remaining: 32s
# 12:	learn: 0.4671436	total: 425ms	remaining: 32.3s
# 13:	learn: 0.4635790	total: 456ms	remaining: 32.1s
# 14:	learn: 0.4609367	total: 485ms	remaining: 31.9s
# 15:	learn: 0.4584063	total: 543ms	remaining: 33.4s
# 16:	learn: 0.4572097	total: 580ms	remaining: 33.5s
# 17:	learn: 0.4556517	total: 612ms	remaining: 33.4s
# 18:	learn: 0.4539942	total: 643ms	remaining: 33.2s
# 19:	learn: 0.4524628	total: 675ms	remaining: 33.1s
# 20:	learn: 0.4511240	total: 703ms	remaining: 32.8s
# 21:	learn: 0.4493927	total: 736ms	remaining: 32.7s
# 22:	learn: 0.4481194	total: 773ms	remaining: 32.8s
# 23:	learn: 0.4468785	total: 822ms	remaining: 33.4s
# 24:	learn: 0.4462613	total: 887ms	remaining: 34.6s
# 25:	learn: 0.4450160	total: 952ms	remaining: 35.7s
# 26:	learn: 0.4440013	total: 1.03s	remaining: 37.1s
# 27:	learn: 0.4429068	total: 1.1s	remaining: 38.4s
# 28:	learn: 0.4421541	total: 1.18s	remaining: 39.5s
# 29:	learn: 0.4410796	total: 1.25s	remaining: 40.5s
# 30:	learn: 0.4404621	total: 1.32s	remaining: 41.3s
# 31:	learn: 0.4395058	total: 1.4s	remaining: 42.3s
# 32:	learn: 0.4382206	total: 1.49s	remaining: 43.6s
# 33:	learn: 0.4377905	total: 1.57s	remaining: 44.6s
# 34:	learn: 0.4370513	total: 1.65s	remaining: 45.6s
# 35:	learn: 0.4363745	total: 1.73s	remaining: 46.4s
# 36:	learn: 0.4357575	total: 1.78s	remaining: 46.2s
# 37:	learn: 0.4351703	total: 1.83s	remaining: 46.3s
# 38:	learn: 0.4343039	total: 1.87s	remaining: 46.1s
# 39:	learn: 0.4338808	total: 1.95s	remaining: 46.7s
# 40:	learn: 0.4332932	total: 2.02s	remaining: 47.3s
# 41:	learn: 0.4327780	total: 2.08s	remaining: 47.4s
# 42:	learn: 0.4323686	total: 2.17s	remaining: 48.2s
# 43:	learn: 0.4316748	total: 2.24s	remaining: 48.7s
# 44:	learn: 0.4308945	total: 2.32s	remaining: 49.3s
# 45:	learn: 0.4301275	total: 2.39s	remaining: 49.5s
# 46:	learn: 0.4292951	total: 2.45s	remaining: 49.7s
# 47:	learn: 0.4284736	total: 2.52s	remaining: 49.9s
# 48:	learn: 0.4279247	total: 2.6s	remaining: 50.4s
# 49:	learn: 0.4270810	total: 2.67s	remaining: 50.8s
# 50:	learn: 0.4265261	total: 2.72s	remaining: 50.6s
# 51:	learn: 0.4257992	total: 2.78s	remaining: 50.7s
# 52:	learn: 0.4252627	total: 2.86s	remaining: 51.1s
# 53:	learn: 0.4248422	total: 2.94s	remaining: 51.6s
# 54:	learn: 0.4240625	total: 3.02s	remaining: 52s
# 55:	learn: 0.4237179	total: 3.1s	remaining: 52.3s
# 56:	learn: 0.4230156	total: 3.18s	remaining: 52.7s
# 57:	learn: 0.4223721	total: 3.26s	remaining: 52.9s
# 58:	learn: 0.4215290	total: 3.32s	remaining: 53s
# 59:	learn: 0.4210186	total: 3.37s	remaining: 52.8s
# 60:	learn: 0.4204407	total: 3.42s	remaining: 52.6s
# 61:	learn: 0.4200123	total: 3.49s	remaining: 52.9s
# 62:	learn: 0.4196451	total: 3.58s	remaining: 53.2s
# 63:	learn: 0.4191411	total: 3.66s	remaining: 53.6s
# 64:	learn: 0.4187112	total: 3.74s	remaining: 53.8s
# 65:	learn: 0.4180404	total: 3.83s	remaining: 54.2s
# 66:	learn: 0.4175949	total: 3.9s	remaining: 54.4s
# 67:	learn: 0.4170629	total: 3.96s	remaining: 54.3s
# 68:	learn: 0.4165002	total: 4.02s	remaining: 54.3s
# 69:	learn: 0.4161348	total: 4.09s	remaining: 54.4s
# 70:	learn: 0.4157136	total: 4.15s	remaining: 54.3s
# 71:	learn: 0.4153104	total: 4.23s	remaining: 54.6s
# 72:	learn: 0.4149825	total: 4.29s	remaining: 54.5s
# 73:	learn: 0.4146288	total: 4.36s	remaining: 54.5s
# 74:	learn: 0.4142646	total: 4.42s	remaining: 54.6s
# 75:	learn: 0.4139208	total: 4.51s	remaining: 54.8s
# 76:	learn: 0.4135736	total: 4.57s	remaining: 54.8s
# 77:	learn: 0.4132061	total: 4.62s	remaining: 54.6s
# 78:	learn: 0.4126992	total: 4.69s	remaining: 54.7s
# 79:	learn: 0.4122908	total: 4.78s	remaining: 55s
# 80:	learn: 0.4119692	total: 4.86s	remaining: 55.1s
# 81:	learn: 0.4115726	total: 4.93s	remaining: 55.2s
# 82:	learn: 0.4109843	total: 5.01s	remaining: 55.4s
# 83:	learn: 0.4107265	total: 5.08s	remaining: 55.4s
# 84:	learn: 0.4103934	total: 5.17s	remaining: 55.6s
# 85:	learn: 0.4099453	total: 5.25s	remaining: 55.8s
# 86:	learn: 0.4095057	total: 5.3s	remaining: 55.6s
# 87:	learn: 0.4091772	total: 5.4s	remaining: 55.9s
# 88:	learn: 0.4090045	total: 5.44s	remaining: 55.7s
# 89:	learn: 0.4086285	total: 5.51s	remaining: 55.8s
# 90:	learn: 0.4082987	total: 5.59s	remaining: 55.9s
# 91:	learn: 0.4077466	total: 5.65s	remaining: 55.8s
# 92:	learn: 0.4072495	total: 5.72s	remaining: 55.8s
# 93:	learn: 0.4068340	total: 5.81s	remaining: 56s
# 94:	learn: 0.4064377	total: 5.87s	remaining: 55.9s
# 95:	learn: 0.4058207	total: 5.95s	remaining: 56.1s
# 96:	learn: 0.4055889	total: 6s	remaining: 55.9s
# 97:	learn: 0.4052789	total: 6.03s	remaining: 55.5s
# 98:	learn: 0.4048391	total: 6.06s	remaining: 55.2s
# 99:	learn: 0.4046274	total: 6.09s	remaining: 54.9s
# 100:	learn: 0.4042113	total: 6.13s	remaining: 54.5s
# 101:	learn: 0.4038890	total: 6.17s	remaining: 54.3s
# 102:	learn: 0.4035940	total: 6.21s	remaining: 54s
# 103:	learn: 0.4031975	total: 6.24s	remaining: 53.7s
# 104:	learn: 0.4026538	total: 6.27s	remaining: 53.5s
# 105:	learn: 0.4023088	total: 6.31s	remaining: 53.2s
# 106:	learn: 0.4015153	total: 6.34s	remaining: 52.9s
# 107:	learn: 0.4012274	total: 6.38s	remaining: 52.7s
# 108:	learn: 0.4009639	total: 6.41s	remaining: 52.4s
# 109:	learn: 0.4004529	total: 6.44s	remaining: 52.1s
# 110:	learn: 0.4001914	total: 6.47s	remaining: 51.8s
# 111:	learn: 0.3998714	total: 6.51s	remaining: 51.6s
# 112:	learn: 0.3996342	total: 6.54s	remaining: 51.3s
# 113:	learn: 0.3992008	total: 6.57s	remaining: 51s
# 114:	learn: 0.3987031	total: 6.61s	remaining: 50.8s
# 115:	learn: 0.3983175	total: 6.64s	remaining: 50.6s
# 116:	learn: 0.3981041	total: 6.67s	remaining: 50.3s
# 117:	learn: 0.3976811	total: 6.7s	remaining: 50.1s
# 118:	learn: 0.3973637	total: 6.74s	remaining: 49.9s
# 119:	learn: 0.3970585	total: 6.77s	remaining: 49.6s
# 120:	learn: 0.3963047	total: 6.83s	remaining: 49.6s
# 121:	learn: 0.3959000	total: 6.86s	remaining: 49.4s
# 122:	learn: 0.3954457	total: 6.89s	remaining: 49.1s
# 123:	learn: 0.3951151	total: 6.92s	remaining: 48.9s
# 124:	learn: 0.3948773	total: 6.96s	remaining: 48.7s
# 125:	learn: 0.3944701	total: 6.99s	remaining: 48.5s
# 126:	learn: 0.3938595	total: 7.03s	remaining: 48.3s
# 127:	learn: 0.3935895	total: 7.06s	remaining: 48.1s
# 128:	learn: 0.3934219	total: 7.09s	remaining: 47.9s
# 129:	learn: 0.3932437	total: 7.12s	remaining: 47.7s
# 130:	learn: 0.3929616	total: 7.17s	remaining: 47.6s
# 131:	learn: 0.3926917	total: 7.2s	remaining: 47.3s
# 132:	learn: 0.3925226	total: 7.24s	remaining: 47.2s
# 133:	learn: 0.3922366	total: 7.27s	remaining: 47s
# 134:	learn: 0.3918155	total: 7.29s	remaining: 46.7s
# 135:	learn: 0.3915028	total: 7.33s	remaining: 46.5s
# 136:	learn: 0.3913773	total: 7.36s	remaining: 46.4s
# 137:	learn: 0.3910193	total: 7.39s	remaining: 46.2s
# 138:	learn: 0.3906759	total: 7.42s	remaining: 46s
# 139:	learn: 0.3905298	total: 7.46s	remaining: 45.8s
# 140:	learn: 0.3900945	total: 7.49s	remaining: 45.6s
# 141:	learn: 0.3899215	total: 7.52s	remaining: 45.5s
# 142:	learn: 0.3897469	total: 7.55s	remaining: 45.3s
# 143:	learn: 0.3894880	total: 7.59s	remaining: 45.1s
# 144:	learn: 0.3892677	total: 7.62s	remaining: 44.9s
# 145:	learn: 0.3888914	total: 7.65s	remaining: 44.8s
# 146:	learn: 0.3887036	total: 7.69s	remaining: 44.6s
# 147:	learn: 0.3885070	total: 7.72s	remaining: 44.4s
# 148:	learn: 0.3881811	total: 7.75s	remaining: 44.3s
# 149:	learn: 0.3880169	total: 7.79s	remaining: 44.1s
# 150:	learn: 0.3877628	total: 7.84s	remaining: 44.1s
# 151:	learn: 0.3875725	total: 7.87s	remaining: 43.9s
# 152:	learn: 0.3873355	total: 7.9s	remaining: 43.7s
# 153:	learn: 0.3871588	total: 7.93s	remaining: 43.6s
# 154:	learn: 0.3867947	total: 7.96s	remaining: 43.4s
# 155:	learn: 0.3864992	total: 7.99s	remaining: 43.2s
# 156:	learn: 0.3862021	total: 8.03s	remaining: 43.1s
# 157:	learn: 0.3858928	total: 8.06s	remaining: 43s
# 158:	learn: 0.3856114	total: 8.09s	remaining: 42.8s
# 159:	learn: 0.3854269	total: 8.13s	remaining: 42.7s
# 160:	learn: 0.3852094	total: 8.16s	remaining: 42.5s
# 161:	learn: 0.3849946	total: 8.19s	remaining: 42.4s
# 162:	learn: 0.3845093	total: 8.23s	remaining: 42.3s
# 163:	learn: 0.3843003	total: 8.26s	remaining: 42.1s
# 164:	learn: 0.3839949	total: 8.29s	remaining: 42s
# 165:	learn: 0.3836935	total: 8.32s	remaining: 41.8s
# 166:	learn: 0.3834592	total: 8.36s	remaining: 41.7s
# 167:	learn: 0.3832025	total: 8.39s	remaining: 41.6s
# 168:	learn: 0.3830575	total: 8.42s	remaining: 41.4s
# 169:	learn: 0.3825862	total: 8.46s	remaining: 41.3s
# 170:	learn: 0.3822016	total: 8.49s	remaining: 41.2s
# 171:	learn: 0.3820389	total: 8.52s	remaining: 41s
# 172:	learn: 0.3817373	total: 8.55s	remaining: 40.9s
# 173:	learn: 0.3815490	total: 8.59s	remaining: 40.8s
# 174:	learn: 0.3813668	total: 8.62s	remaining: 40.6s
# 175:	learn: 0.3811599	total: 8.64s	remaining: 40.5s
# 176:	learn: 0.3809737	total: 8.68s	remaining: 40.3s
# 177:	learn: 0.3807283	total: 8.71s	remaining: 40.2s
# 178:	learn: 0.3803901	total: 8.74s	remaining: 40.1s
# 179:	learn: 0.3802459	total: 8.78s	remaining: 40s
# 180:	learn: 0.3800282	total: 8.81s	remaining: 39.9s
# 181:	learn: 0.3797570	total: 8.87s	remaining: 39.8s
# 182:	learn: 0.3795730	total: 8.9s	remaining: 39.7s
# 183:	learn: 0.3792772	total: 8.93s	remaining: 39.6s
# 184:	learn: 0.3790708	total: 8.96s	remaining: 39.5s
# 185:	learn: 0.3789282	total: 8.99s	remaining: 39.4s
# 186:	learn: 0.3788018	total: 9.03s	remaining: 39.3s
# 187:	learn: 0.3785945	total: 9.06s	remaining: 39.1s
# 188:	learn: 0.3783047	total: 9.09s	remaining: 39s
# 189:	learn: 0.3779612	total: 9.12s	remaining: 38.9s
# 190:	learn: 0.3777407	total: 9.16s	remaining: 38.8s
# 191:	learn: 0.3772089	total: 9.19s	remaining: 38.7s
# 192:	learn: 0.3769148	total: 9.22s	remaining: 38.6s
# 193:	learn: 0.3766261	total: 9.26s	remaining: 38.5s
# 194:	learn: 0.3765098	total: 9.29s	remaining: 38.3s
# 195:	learn: 0.3763490	total: 9.32s	remaining: 38.2s
# 196:	learn: 0.3760635	total: 9.35s	remaining: 38.1s
# 197:	learn: 0.3758719	total: 9.38s	remaining: 38s
# 198:	learn: 0.3756213	total: 9.41s	remaining: 37.9s
# 199:	learn: 0.3754148	total: 9.44s	remaining: 37.8s
# 200:	learn: 0.3750493	total: 9.48s	remaining: 37.7s
# 201:	learn: 0.3746901	total: 9.52s	remaining: 37.6s
# 202:	learn: 0.3744387	total: 9.54s	remaining: 37.5s
# 203:	learn: 0.3742362	total: 9.57s	remaining: 37.4s
# 204:	learn: 0.3740915	total: 9.61s	remaining: 37.3s
# 205:	learn: 0.3738511	total: 9.64s	remaining: 37.1s
# 206:	learn: 0.3735899	total: 9.67s	remaining: 37s
# 207:	learn: 0.3734458	total: 9.71s	remaining: 37s
# 208:	learn: 0.3732253	total: 9.74s	remaining: 36.9s
# 209:	learn: 0.3730824	total: 9.77s	remaining: 36.8s
# 210:	learn: 0.3727297	total: 9.8s	remaining: 36.7s
# 211:	learn: 0.3724263	total: 9.84s	remaining: 36.6s
# 212:	learn: 0.3722471	total: 9.9s	remaining: 36.6s
# 213:	learn: 0.3721198	total: 9.94s	remaining: 36.5s
# 214:	learn: 0.3719013	total: 9.97s	remaining: 36.4s
# 215:	learn: 0.3716422	total: 10s	remaining: 36.3s
# 216:	learn: 0.3714160	total: 10s	remaining: 36.2s
# 217:	learn: 0.3711752	total: 10.1s	remaining: 36.1s
# 218:	learn: 0.3709120	total: 10.1s	remaining: 36s
# 219:	learn: 0.3707477	total: 10.1s	remaining: 36s
# 220:	learn: 0.3706104	total: 10.2s	remaining: 35.9s
# 221:	learn: 0.3703834	total: 10.2s	remaining: 35.7s
# 222:	learn: 0.3702596	total: 10.2s	remaining: 35.7s
# 223:	learn: 0.3699770	total: 10.3s	remaining: 35.6s
# 224:	learn: 0.3697056	total: 10.3s	remaining: 35.5s
# 225:	learn: 0.3695241	total: 10.3s	remaining: 35.4s
# 226:	learn: 0.3690683	total: 10.4s	remaining: 35.3s
# 227:	learn: 0.3688092	total: 10.4s	remaining: 35.2s
# 228:	learn: 0.3687117	total: 10.4s	remaining: 35.2s
# 229:	learn: 0.3684818	total: 10.5s	remaining: 35.1s
# 230:	learn: 0.3683663	total: 10.5s	remaining: 35s
# 231:	learn: 0.3681268	total: 10.5s	remaining: 34.9s
# 232:	learn: 0.3678984	total: 10.6s	remaining: 34.8s
# 233:	learn: 0.3675838	total: 10.6s	remaining: 34.7s
# 234:	learn: 0.3672461	total: 10.6s	remaining: 34.7s
# 235:	learn: 0.3668689	total: 10.7s	remaining: 34.6s
# 236:	learn: 0.3666458	total: 10.7s	remaining: 34.5s
# 237:	learn: 0.3664464	total: 10.7s	remaining: 34.4s
# 238:	learn: 0.3663055	total: 10.8s	remaining: 34.3s
# 239:	learn: 0.3661400	total: 10.8s	remaining: 34.2s
# 240:	learn: 0.3659348	total: 10.8s	remaining: 34.2s
# 241:	learn: 0.3656978	total: 10.9s	remaining: 34.1s
# 242:	learn: 0.3654830	total: 10.9s	remaining: 34.1s
# 243:	learn: 0.3652092	total: 11s	remaining: 34s
# 244:	learn: 0.3649525	total: 11s	remaining: 33.9s
# 245:	learn: 0.3647808	total: 11s	remaining: 33.8s
# 246:	learn: 0.3645180	total: 11.1s	remaining: 33.8s
# 247:	learn: 0.3642915	total: 11.1s	remaining: 33.7s
# 248:	learn: 0.3640595	total: 11.2s	remaining: 33.6s
# 249:	learn: 0.3637824	total: 11.2s	remaining: 33.6s
# 250:	learn: 0.3633995	total: 11.2s	remaining: 33.5s
# 251:	learn: 0.3632486	total: 11.3s	remaining: 33.4s
# 252:	learn: 0.3630281	total: 11.3s	remaining: 33.3s
# 253:	learn: 0.3628267	total: 11.3s	remaining: 33.2s
# 254:	learn: 0.3625337	total: 11.3s	remaining: 33.1s
# 255:	learn: 0.3623661	total: 11.4s	remaining: 33.1s
# 256:	learn: 0.3622018	total: 11.4s	remaining: 33s
# 257:	learn: 0.3621030	total: 11.4s	remaining: 32.9s
# 258:	learn: 0.3619103	total: 11.5s	remaining: 32.8s
# 259:	learn: 0.3617843	total: 11.5s	remaining: 32.7s
# 260:	learn: 0.3615872	total: 11.5s	remaining: 32.7s
# 261:	learn: 0.3614384	total: 11.6s	remaining: 32.6s
# 262:	learn: 0.3612319	total: 11.6s	remaining: 32.5s
# 263:	learn: 0.3610323	total: 11.6s	remaining: 32.4s
# 264:	learn: 0.3609014	total: 11.7s	remaining: 32.4s
# 265:	learn: 0.3608217	total: 11.7s	remaining: 32.3s
# 266:	learn: 0.3606190	total: 11.7s	remaining: 32.2s
# 267:	learn: 0.3603826	total: 11.8s	remaining: 32.1s
# 268:	learn: 0.3602051	total: 11.8s	remaining: 32s
# 269:	learn: 0.3600013	total: 11.8s	remaining: 32s
# 270:	learn: 0.3598283	total: 11.9s	remaining: 31.9s
# 271:	learn: 0.3596455	total: 11.9s	remaining: 31.8s
# 272:	learn: 0.3595008	total: 11.9s	remaining: 31.8s
# 273:	learn: 0.3592782	total: 12s	remaining: 31.7s
# 274:	learn: 0.3591257	total: 12s	remaining: 31.7s
# 275:	learn: 0.3590094	total: 12s	remaining: 31.6s
# 276:	learn: 0.3588133	total: 12.1s	remaining: 31.5s
# 277:	learn: 0.3586927	total: 12.1s	remaining: 31.5s
# 278:	learn: 0.3584297	total: 12.2s	remaining: 31.4s
# 279:	learn: 0.3582701	total: 12.2s	remaining: 31.3s
# 280:	learn: 0.3581195	total: 12.2s	remaining: 31.3s
# 281:	learn: 0.3579608	total: 12.2s	remaining: 31.2s
# 282:	learn: 0.3577874	total: 12.3s	remaining: 31.1s
# 283:	learn: 0.3576527	total: 12.3s	remaining: 31s
# 284:	learn: 0.3574709	total: 12.3s	remaining: 31s
# 285:	learn: 0.3572912	total: 12.4s	remaining: 30.9s
# 286:	learn: 0.3571359	total: 12.4s	remaining: 30.8s
# 287:	learn: 0.3569760	total: 12.4s	remaining: 30.8s
# 288:	learn: 0.3568653	total: 12.5s	remaining: 30.7s
# 289:	learn: 0.3566949	total: 12.5s	remaining: 30.6s
# 290:	learn: 0.3565797	total: 12.5s	remaining: 30.5s
# 291:	learn: 0.3563860	total: 12.6s	remaining: 30.5s
# 292:	learn: 0.3562501	total: 12.6s	remaining: 30.4s
# 293:	learn: 0.3561048	total: 12.6s	remaining: 30.4s
# 294:	learn: 0.3559757	total: 12.7s	remaining: 30.3s
# 295:	learn: 0.3558168	total: 12.7s	remaining: 30.2s
# 296:	learn: 0.3556441	total: 12.7s	remaining: 30.2s
# 297:	learn: 0.3554387	total: 12.8s	remaining: 30.1s
# 298:	learn: 0.3552954	total: 12.8s	remaining: 30s
# 299:	learn: 0.3551745	total: 12.8s	remaining: 30s
# 300:	learn: 0.3548911	total: 12.9s	remaining: 29.9s
# 301:	learn: 0.3545709	total: 12.9s	remaining: 29.8s
# 302:	learn: 0.3544335	total: 13s	remaining: 29.8s
# 303:	learn: 0.3542967	total: 13s	remaining: 29.7s
# 304:	learn: 0.3542217	total: 13s	remaining: 29.7s
# 305:	learn: 0.3540692	total: 13.1s	remaining: 29.6s
# 306:	learn: 0.3539574	total: 13.1s	remaining: 29.6s
# 307:	learn: 0.3537354	total: 13.1s	remaining: 29.5s
# 308:	learn: 0.3536010	total: 13.2s	remaining: 29.5s
# 309:	learn: 0.3534553	total: 13.2s	remaining: 29.4s
# 310:	learn: 0.3533056	total: 13.2s	remaining: 29.3s
# 311:	learn: 0.3531725	total: 13.3s	remaining: 29.3s
# 312:	learn: 0.3530017	total: 13.3s	remaining: 29.2s
# 313:	learn: 0.3528720	total: 13.3s	remaining: 29.1s
# 314:	learn: 0.3527289	total: 13.4s	remaining: 29.1s
# 315:	learn: 0.3525724	total: 13.4s	remaining: 29s
# 316:	learn: 0.3524116	total: 13.4s	remaining: 29s
# 317:	learn: 0.3523025	total: 13.5s	remaining: 28.9s
# 318:	learn: 0.3521965	total: 13.5s	remaining: 28.8s
# 319:	learn: 0.3520551	total: 13.5s	remaining: 28.8s
# 320:	learn: 0.3519536	total: 13.6s	remaining: 28.7s
# 321:	learn: 0.3517607	total: 13.6s	remaining: 28.6s
# 322:	learn: 0.3516620	total: 13.6s	remaining: 28.6s
# 323:	learn: 0.3514235	total: 13.7s	remaining: 28.5s
# 324:	learn: 0.3513253	total: 13.7s	remaining: 28.4s
# 325:	learn: 0.3512001	total: 13.7s	remaining: 28.4s
# 326:	learn: 0.3510763	total: 13.8s	remaining: 28.3s
# 327:	learn: 0.3509835	total: 13.8s	remaining: 28.3s
# 328:	learn: 0.3508532	total: 13.8s	remaining: 28.2s
# 329:	learn: 0.3507021	total: 13.9s	remaining: 28.1s
# 330:	learn: 0.3504928	total: 13.9s	remaining: 28.1s
# 331:	learn: 0.3503546	total: 13.9s	remaining: 28s
# 332:	learn: 0.3501435	total: 14s	remaining: 28s
# 333:	learn: 0.3499514	total: 14s	remaining: 27.9s
# 334:	learn: 0.3498807	total: 14s	remaining: 27.9s
# 335:	learn: 0.3497381	total: 14.1s	remaining: 27.8s
# 336:	learn: 0.3495835	total: 14.1s	remaining: 27.8s
# 337:	learn: 0.3494594	total: 14.2s	remaining: 27.7s
# 338:	learn: 0.3493580	total: 14.2s	remaining: 27.7s
# 339:	learn: 0.3492166	total: 14.2s	remaining: 27.6s
# 340:	learn: 0.3490481	total: 14.3s	remaining: 27.5s
# 341:	learn: 0.3488172	total: 14.3s	remaining: 27.5s
# 342:	learn: 0.3486527	total: 14.3s	remaining: 27.4s
# 343:	learn: 0.3483472	total: 14.4s	remaining: 27.4s
# 344:	learn: 0.3482286	total: 14.4s	remaining: 27.3s
# 345:	learn: 0.3480888	total: 14.4s	remaining: 27.3s
# 346:	learn: 0.3479974	total: 14.5s	remaining: 27.2s
# 347:	learn: 0.3478436	total: 14.5s	remaining: 27.1s
# 348:	learn: 0.3477083	total: 14.5s	remaining: 27.1s
# 349:	learn: 0.3475715	total: 14.6s	remaining: 27s
# 350:	learn: 0.3474544	total: 14.6s	remaining: 27s
# 351:	learn: 0.3473003	total: 14.6s	remaining: 26.9s
# 352:	learn: 0.3471337	total: 14.7s	remaining: 26.9s
# 353:	learn: 0.3470200	total: 14.7s	remaining: 26.8s
# 354:	learn: 0.3469093	total: 14.7s	remaining: 26.8s
# 355:	learn: 0.3466768	total: 14.8s	remaining: 26.7s
# 356:	learn: 0.3465265	total: 14.8s	remaining: 26.6s
# 357:	learn: 0.3462681	total: 14.8s	remaining: 26.6s
# 358:	learn: 0.3461215	total: 14.9s	remaining: 26.5s
# 359:	learn: 0.3460356	total: 14.9s	remaining: 26.5s
# 360:	learn: 0.3458634	total: 14.9s	remaining: 26.4s
# 361:	learn: 0.3457524	total: 15s	remaining: 26.4s
# 362:	learn: 0.3456427	total: 15s	remaining: 26.4s
# 363:	learn: 0.3455167	total: 15.1s	remaining: 26.3s
# 364:	learn: 0.3453867	total: 15.1s	remaining: 26.3s
# 365:	learn: 0.3452604	total: 15.1s	remaining: 26.2s
# 366:	learn: 0.3450925	total: 15.2s	remaining: 26.1s
# 367:	learn: 0.3449975	total: 15.2s	remaining: 26.1s
# 368:	learn: 0.3448400	total: 15.2s	remaining: 26s
# 369:	learn: 0.3446951	total: 15.3s	remaining: 26s
# 370:	learn: 0.3445403	total: 15.3s	remaining: 25.9s
# 371:	learn: 0.3443914	total: 15.3s	remaining: 25.9s
# 372:	learn: 0.3442479	total: 15.4s	remaining: 25.8s
# 373:	learn: 0.3440488	total: 15.4s	remaining: 25.8s
# 374:	learn: 0.3439333	total: 15.4s	remaining: 25.7s
# 375:	learn: 0.3437223	total: 15.5s	remaining: 25.6s
# 376:	learn: 0.3436160	total: 15.5s	remaining: 25.6s
# 377:	learn: 0.3434631	total: 15.5s	remaining: 25.5s
# 378:	learn: 0.3432735	total: 15.6s	remaining: 25.5s
# 379:	learn: 0.3431788	total: 15.6s	remaining: 25.4s
# 380:	learn: 0.3430975	total: 15.6s	remaining: 25.4s
# 381:	learn: 0.3429444	total: 15.6s	remaining: 25.3s
# 382:	learn: 0.3428264	total: 15.7s	remaining: 25.3s
# 383:	learn: 0.3426577	total: 15.7s	remaining: 25.2s
# 384:	learn: 0.3425344	total: 15.7s	remaining: 25.1s
# 385:	learn: 0.3423543	total: 15.8s	remaining: 25.1s
# 386:	learn: 0.3422328	total: 15.8s	remaining: 25s
# 387:	learn: 0.3420787	total: 15.8s	remaining: 25s
# 388:	learn: 0.3419372	total: 15.9s	remaining: 24.9s
# 389:	learn: 0.3418257	total: 15.9s	remaining: 24.9s
# 390:	learn: 0.3417669	total: 16s	remaining: 24.9s
# 391:	learn: 0.3416758	total: 16.1s	remaining: 24.9s
# 392:	learn: 0.3414894	total: 16.2s	remaining: 24.9s
# 393:	learn: 0.3412999	total: 16.2s	remaining: 24.9s
# 394:	learn: 0.3412278	total: 16.3s	remaining: 24.9s
# 395:	learn: 0.3410880	total: 16.4s	remaining: 25s
# 396:	learn: 0.3410067	total: 16.4s	remaining: 25s
# 397:	learn: 0.3408608	total: 16.5s	remaining: 24.9s
# 398:	learn: 0.3407645	total: 16.5s	remaining: 24.9s
# 399:	learn: 0.3406035	total: 16.6s	remaining: 24.9s
# 400:	learn: 0.3404814	total: 16.7s	remaining: 24.9s
# 401:	learn: 0.3404166	total: 16.8s	remaining: 24.9s
# 402:	learn: 0.3403127	total: 16.8s	remaining: 24.9s
# 403:	learn: 0.3401590	total: 16.9s	remaining: 24.9s
# 404:	learn: 0.3399664	total: 17s	remaining: 24.9s
# 405:	learn: 0.3398416	total: 17s	remaining: 24.9s
# 406:	learn: 0.3397441	total: 17.1s	remaining: 25s
# 407:	learn: 0.3396386	total: 17.2s	remaining: 25s
# 408:	learn: 0.3394955	total: 17.3s	remaining: 25s
# 409:	learn: 0.3392985	total: 17.4s	remaining: 25s
# 410:	learn: 0.3392094	total: 17.4s	remaining: 25s
# 411:	learn: 0.3390322	total: 17.5s	remaining: 25s
# 412:	learn: 0.3389270	total: 17.6s	remaining: 25s
# 413:	learn: 0.3388422	total: 17.6s	remaining: 24.9s
# 414:	learn: 0.3387166	total: 17.7s	remaining: 24.9s
# 415:	learn: 0.3386079	total: 17.8s	remaining: 24.9s
# 416:	learn: 0.3384888	total: 17.8s	remaining: 24.9s
# 417:	learn: 0.3383186	total: 17.9s	remaining: 24.9s
# 418:	learn: 0.3382001	total: 17.9s	remaining: 24.9s
# 419:	learn: 0.3381238	total: 18s	remaining: 24.8s
# 420:	learn: 0.3379481	total: 18.1s	remaining: 24.9s
# 421:	learn: 0.3378182	total: 18.2s	remaining: 24.9s
# 422:	learn: 0.3377100	total: 18.2s	remaining: 24.9s
# 423:	learn: 0.3376140	total: 18.3s	remaining: 24.8s
# 424:	learn: 0.3374635	total: 18.3s	remaining: 24.8s
# 425:	learn: 0.3373550	total: 18.4s	remaining: 24.7s
# 426:	learn: 0.3372306	total: 18.4s	remaining: 24.8s
# 427:	learn: 0.3371075	total: 18.5s	remaining: 24.8s
# 428:	learn: 0.3370172	total: 18.6s	remaining: 24.8s
# 429:	learn: 0.3369098	total: 18.7s	remaining: 24.7s
# 430:	learn: 0.3367785	total: 18.7s	remaining: 24.8s
# 431:	learn: 0.3367023	total: 18.8s	remaining: 24.8s
# 432:	learn: 0.3365763	total: 18.9s	remaining: 24.8s
# 433:	learn: 0.3363863	total: 19s	remaining: 24.8s
# 434:	learn: 0.3362662	total: 19.1s	remaining: 24.8s
# 435:	learn: 0.3361505	total: 19.2s	remaining: 24.8s
# 436:	learn: 0.3359950	total: 19.2s	remaining: 24.8s
# 437:	learn: 0.3358856	total: 19.3s	remaining: 24.8s
# 438:	learn: 0.3358055	total: 19.4s	remaining: 24.7s
# 439:	learn: 0.3356985	total: 19.4s	remaining: 24.7s
# 440:	learn: 0.3355816	total: 19.5s	remaining: 24.7s
# 441:	learn: 0.3354956	total: 19.6s	remaining: 24.7s
# 442:	learn: 0.3353570	total: 19.7s	remaining: 24.7s
# 443:	learn: 0.3352059	total: 19.7s	remaining: 24.7s
# 444:	learn: 0.3351185	total: 19.8s	remaining: 24.7s
# 445:	learn: 0.3350005	total: 19.9s	remaining: 24.7s
# 446:	learn: 0.3348750	total: 20s	remaining: 24.7s
# 447:	learn: 0.3347244	total: 20s	remaining: 24.7s
# 448:	learn: 0.3346066	total: 20.1s	remaining: 24.7s
# 449:	learn: 0.3345221	total: 20.2s	remaining: 24.7s
# 450:	learn: 0.3344230	total: 20.3s	remaining: 24.7s
# 451:	learn: 0.3343267	total: 20.4s	remaining: 24.7s
# 452:	learn: 0.3342445	total: 20.4s	remaining: 24.7s
# 453:	learn: 0.3341036	total: 20.5s	remaining: 24.7s
# 454:	learn: 0.3339790	total: 20.6s	remaining: 24.7s
# 455:	learn: 0.3339103	total: 20.7s	remaining: 24.7s
# 456:	learn: 0.3338499	total: 20.7s	remaining: 24.7s
# 457:	learn: 0.3337432	total: 20.8s	remaining: 24.7s
# 458:	learn: 0.3335490	total: 20.9s	remaining: 24.6s
# 459:	learn: 0.3334185	total: 21s	remaining: 24.6s
# 460:	learn: 0.3333412	total: 21.1s	remaining: 24.6s
# 461:	learn: 0.3332847	total: 21.1s	remaining: 24.6s
# 462:	learn: 0.3332049	total: 21.2s	remaining: 24.6s
# 463:	learn: 0.3330624	total: 21.3s	remaining: 24.6s
# 464:	learn: 0.3329648	total: 21.4s	remaining: 24.6s
# 465:	learn: 0.3328671	total: 21.5s	remaining: 24.6s
# 466:	learn: 0.3327097	total: 21.5s	remaining: 24.6s
# 467:	learn: 0.3325962	total: 21.6s	remaining: 24.5s
# 468:	learn: 0.3325428	total: 21.6s	remaining: 24.5s
# 469:	learn: 0.3323755	total: 21.6s	remaining: 24.4s
# 470:	learn: 0.3322565	total: 21.7s	remaining: 24.3s
# 471:	learn: 0.3321652	total: 21.7s	remaining: 24.3s
# 472:	learn: 0.3320793	total: 21.7s	remaining: 24.2s
# 473:	learn: 0.3319987	total: 21.8s	remaining: 24.1s
# 474:	learn: 0.3319468	total: 21.8s	remaining: 24.1s
# 475:	learn: 0.3318708	total: 21.8s	remaining: 24s
# 476:	learn: 0.3317696	total: 21.9s	remaining: 24s
# 477:	learn: 0.3316895	total: 21.9s	remaining: 23.9s
# 478:	learn: 0.3316260	total: 21.9s	remaining: 23.8s
# 479:	learn: 0.3314995	total: 21.9s	remaining: 23.8s
# 480:	learn: 0.3314348	total: 22s	remaining: 23.7s
# 481:	learn: 0.3313255	total: 22s	remaining: 23.7s
# 482:	learn: 0.3312505	total: 22.1s	remaining: 23.6s
# 483:	learn: 0.3310792	total: 22.1s	remaining: 23.6s
# 484:	learn: 0.3309958	total: 22.1s	remaining: 23.5s
# 485:	learn: 0.3308980	total: 22.2s	remaining: 23.4s
# 486:	learn: 0.3308181	total: 22.2s	remaining: 23.4s
# 487:	learn: 0.3307005	total: 22.2s	remaining: 23.3s
# 488:	learn: 0.3306356	total: 22.2s	remaining: 23.2s
# 489:	learn: 0.3305079	total: 22.3s	remaining: 23.2s
# 490:	learn: 0.3303044	total: 22.3s	remaining: 23.1s
# 491:	learn: 0.3302202	total: 22.3s	remaining: 23.1s
# 492:	learn: 0.3301374	total: 22.4s	remaining: 23s
# 493:	learn: 0.3300771	total: 22.4s	remaining: 23s
# 494:	learn: 0.3300037	total: 22.5s	remaining: 22.9s
# 495:	learn: 0.3297505	total: 22.5s	remaining: 22.9s
# 496:	learn: 0.3296477	total: 22.5s	remaining: 22.8s
# 497:	learn: 0.3294947	total: 22.6s	remaining: 22.8s
# 498:	learn: 0.3293977	total: 22.6s	remaining: 22.7s
# 499:	learn: 0.3293443	total: 22.6s	remaining: 22.6s
# 500:	learn: 0.3292531	total: 22.7s	remaining: 22.6s
# 501:	learn: 0.3291788	total: 22.7s	remaining: 22.5s
# 502:	learn: 0.3289599	total: 22.7s	remaining: 22.5s
# 503:	learn: 0.3288540	total: 22.8s	remaining: 22.4s
# 504:	learn: 0.3288084	total: 22.8s	remaining: 22.3s
# 505:	learn: 0.3286166	total: 22.8s	remaining: 22.3s
# 506:	learn: 0.3284826	total: 22.9s	remaining: 22.2s
# 507:	learn: 0.3283895	total: 22.9s	remaining: 22.2s
# 508:	learn: 0.3282333	total: 22.9s	remaining: 22.1s
# 509:	learn: 0.3281124	total: 23s	remaining: 22.1s
# 510:	learn: 0.3280064	total: 23s	remaining: 22s
# 511:	learn: 0.3279275	total: 23s	remaining: 21.9s
# 512:	learn: 0.3277796	total: 23.1s	remaining: 21.9s
# 513:	learn: 0.3276471	total: 23.1s	remaining: 21.8s
# 514:	learn: 0.3275816	total: 23.1s	remaining: 21.8s
# 515:	learn: 0.3274937	total: 23.2s	remaining: 21.7s
# 516:	learn: 0.3273916	total: 23.2s	remaining: 21.7s
# 517:	learn: 0.3273107	total: 23.2s	remaining: 21.6s
# 518:	learn: 0.3272440	total: 23.3s	remaining: 21.6s
# 519:	learn: 0.3271170	total: 23.3s	remaining: 21.5s
# 520:	learn: 0.3270342	total: 23.3s	remaining: 21.4s
# 521:	learn: 0.3269224	total: 23.4s	remaining: 21.4s
# 522:	learn: 0.3268314	total: 23.4s	remaining: 21.3s
# 523:	learn: 0.3267433	total: 23.4s	remaining: 21.3s
# 524:	learn: 0.3266935	total: 23.5s	remaining: 21.2s
# 525:	learn: 0.3266145	total: 23.5s	remaining: 21.2s
# 526:	learn: 0.3265463	total: 23.5s	remaining: 21.1s
# 527:	learn: 0.3264865	total: 23.6s	remaining: 21.1s
# 528:	learn: 0.3263916	total: 23.6s	remaining: 21s
# 529:	learn: 0.3263104	total: 23.6s	remaining: 21s
# 530:	learn: 0.3262217	total: 23.7s	remaining: 20.9s
# 531:	learn: 0.3261177	total: 23.7s	remaining: 20.8s
# 532:	learn: 0.3260560	total: 23.7s	remaining: 20.8s
# 533:	learn: 0.3259072	total: 23.8s	remaining: 20.7s
# 534:	learn: 0.3258337	total: 23.8s	remaining: 20.7s
# 535:	learn: 0.3257461	total: 23.8s	remaining: 20.6s
# 536:	learn: 0.3256686	total: 23.9s	remaining: 20.6s
# 537:	learn: 0.3255659	total: 23.9s	remaining: 20.5s
# 538:	learn: 0.3255127	total: 23.9s	remaining: 20.5s
# 539:	learn: 0.3254159	total: 24s	remaining: 20.4s
# 540:	learn: 0.3253402	total: 24s	remaining: 20.4s
# 541:	learn: 0.3252831	total: 24s	remaining: 20.3s
# 542:	learn: 0.3251779	total: 24.1s	remaining: 20.3s
# 543:	learn: 0.3250643	total: 24.1s	remaining: 20.2s
# 544:	learn: 0.3250055	total: 24.1s	remaining: 20.1s
# 545:	learn: 0.3248758	total: 24.2s	remaining: 20.1s
# 546:	learn: 0.3247699	total: 24.2s	remaining: 20s
# 547:	learn: 0.3246883	total: 24.2s	remaining: 20s
# 548:	learn: 0.3246113	total: 24.3s	remaining: 19.9s
# 549:	learn: 0.3245218	total: 24.3s	remaining: 19.9s
# 550:	learn: 0.3244540	total: 24.3s	remaining: 19.8s
# 551:	learn: 0.3243479	total: 24.4s	remaining: 19.8s
# 552:	learn: 0.3241727	total: 24.4s	remaining: 19.7s
# 553:	learn: 0.3240674	total: 24.4s	remaining: 19.7s
# 554:	learn: 0.3240153	total: 24.5s	remaining: 19.6s
# 555:	learn: 0.3239591	total: 24.5s	remaining: 19.6s
# 556:	learn: 0.3239004	total: 24.5s	remaining: 19.5s
# 557:	learn: 0.3238473	total: 24.6s	remaining: 19.5s
# 558:	learn: 0.3237310	total: 24.6s	remaining: 19.4s
# 559:	learn: 0.3236698	total: 24.6s	remaining: 19.4s
# 560:	learn: 0.3236092	total: 24.7s	remaining: 19.3s
# 561:	learn: 0.3235428	total: 24.7s	remaining: 19.3s
# 562:	learn: 0.3234821	total: 24.7s	remaining: 19.2s
# 563:	learn: 0.3234245	total: 24.8s	remaining: 19.1s
# 564:	learn: 0.3233739	total: 24.8s	remaining: 19.1s
# 565:	learn: 0.3233134	total: 24.8s	remaining: 19s
# 566:	learn: 0.3232055	total: 24.9s	remaining: 19s
# 567:	learn: 0.3230861	total: 24.9s	remaining: 18.9s
# 568:	learn: 0.3229779	total: 24.9s	remaining: 18.9s
# 569:	learn: 0.3228978	total: 25s	remaining: 18.8s
# 570:	learn: 0.3228551	total: 25s	remaining: 18.8s
# 571:	learn: 0.3227798	total: 25s	remaining: 18.7s
# 572:	learn: 0.3226801	total: 25.1s	remaining: 18.7s
# 573:	learn: 0.3226201	total: 25.1s	remaining: 18.6s
# 574:	learn: 0.3225669	total: 25.1s	remaining: 18.6s
# 575:	learn: 0.3225007	total: 25.2s	remaining: 18.5s
# 576:	learn: 0.3224076	total: 25.2s	remaining: 18.5s
# 577:	learn: 0.3223135	total: 25.2s	remaining: 18.4s
# 578:	learn: 0.3222218	total: 25.3s	remaining: 18.4s
# 579:	learn: 0.3221446	total: 25.3s	remaining: 18.3s
# 580:	learn: 0.3220734	total: 25.3s	remaining: 18.3s
# 581:	learn: 0.3219988	total: 25.4s	remaining: 18.2s
# 582:	learn: 0.3219175	total: 25.4s	remaining: 18.2s
# 583:	learn: 0.3218690	total: 25.4s	remaining: 18.1s
# 584:	learn: 0.3218233	total: 25.5s	remaining: 18.1s
# 585:	learn: 0.3217346	total: 25.5s	remaining: 18s
# 586:	learn: 0.3216335	total: 25.5s	remaining: 18s
# 587:	learn: 0.3215217	total: 25.6s	remaining: 17.9s
# 588:	learn: 0.3214072	total: 25.6s	remaining: 17.9s
# 589:	learn: 0.3213387	total: 25.6s	remaining: 17.8s
# 590:	learn: 0.3212569	total: 25.7s	remaining: 17.8s
# 591:	learn: 0.3212146	total: 25.7s	remaining: 17.7s
# 592:	learn: 0.3211253	total: 25.7s	remaining: 17.7s
# 593:	learn: 0.3210725	total: 25.8s	remaining: 17.6s
# 594:	learn: 0.3210080	total: 25.8s	remaining: 17.6s
# 595:	learn: 0.3209241	total: 25.8s	remaining: 17.5s
# 596:	learn: 0.3208329	total: 25.9s	remaining: 17.5s
# 597:	learn: 0.3207434	total: 25.9s	remaining: 17.4s
# 598:	learn: 0.3206151	total: 25.9s	remaining: 17.4s
# 599:	learn: 0.3205178	total: 26s	remaining: 17.3s
# 600:	learn: 0.3204427	total: 26s	remaining: 17.3s
# 601:	learn: 0.3203985	total: 26s	remaining: 17.2s
# 602:	learn: 0.3202332	total: 26.1s	remaining: 17.2s
# 603:	learn: 0.3201047	total: 26.1s	remaining: 17.1s
# 604:	learn: 0.3200125	total: 26.1s	remaining: 17.1s
# 605:	learn: 0.3199545	total: 26.2s	remaining: 17s
# 606:	learn: 0.3198640	total: 26.2s	remaining: 17s
# 607:	learn: 0.3198050	total: 26.2s	remaining: 16.9s
# 608:	learn: 0.3197451	total: 26.3s	remaining: 16.9s
# 609:	learn: 0.3196963	total: 26.3s	remaining: 16.8s
# 610:	learn: 0.3196405	total: 26.3s	remaining: 16.8s
# 611:	learn: 0.3195814	total: 26.4s	remaining: 16.7s
# 612:	learn: 0.3195389	total: 26.4s	remaining: 16.7s
# 613:	learn: 0.3194626	total: 26.4s	remaining: 16.6s
# 614:	learn: 0.3194196	total: 26.5s	remaining: 16.6s
# 615:	learn: 0.3193507	total: 26.5s	remaining: 16.5s
# 616:	learn: 0.3192722	total: 26.5s	remaining: 16.5s
# 617:	learn: 0.3191942	total: 26.6s	remaining: 16.4s
# 618:	learn: 0.3190973	total: 26.6s	remaining: 16.4s
# 619:	learn: 0.3189672	total: 26.6s	remaining: 16.3s
# 620:	learn: 0.3188937	total: 26.7s	remaining: 16.3s
# 621:	learn: 0.3187926	total: 26.7s	remaining: 16.2s
# 622:	learn: 0.3186488	total: 26.7s	remaining: 16.2s
# 623:	learn: 0.3185692	total: 26.8s	remaining: 16.1s
# 624:	learn: 0.3184767	total: 26.8s	remaining: 16.1s
# 625:	learn: 0.3183849	total: 26.8s	remaining: 16s
# 626:	learn: 0.3181994	total: 26.9s	remaining: 16s
# 627:	learn: 0.3180916	total: 26.9s	remaining: 15.9s
# 628:	learn: 0.3180018	total: 26.9s	remaining: 15.9s
# 629:	learn: 0.3179570	total: 27s	remaining: 15.8s
# 630:	learn: 0.3178615	total: 27s	remaining: 15.8s
# 631:	learn: 0.3177483	total: 27.1s	remaining: 15.8s
# 632:	learn: 0.3176606	total: 27.1s	remaining: 15.7s
# 633:	learn: 0.3176009	total: 27.1s	remaining: 15.7s
# 634:	learn: 0.3175224	total: 27.2s	remaining: 15.6s
# 635:	learn: 0.3174339	total: 27.2s	remaining: 15.6s
# 636:	learn: 0.3173814	total: 27.2s	remaining: 15.5s
# 637:	learn: 0.3172266	total: 27.3s	remaining: 15.5s
# 638:	learn: 0.3171587	total: 27.3s	remaining: 15.4s
# 639:	learn: 0.3170759	total: 27.3s	remaining: 15.4s
# 640:	learn: 0.3170261	total: 27.3s	remaining: 15.3s
# 641:	learn: 0.3169792	total: 27.4s	remaining: 15.3s
# 642:	learn: 0.3169121	total: 27.4s	remaining: 15.2s
# 643:	learn: 0.3168040	total: 27.5s	remaining: 15.2s
# 644:	learn: 0.3167373	total: 27.5s	remaining: 15.1s
# 645:	learn: 0.3166764	total: 27.5s	remaining: 15.1s
# 646:	learn: 0.3166013	total: 27.6s	remaining: 15s
# 647:	learn: 0.3165395	total: 27.6s	remaining: 15s
# 648:	learn: 0.3164843	total: 27.6s	remaining: 14.9s
# 649:	learn: 0.3164458	total: 27.7s	remaining: 14.9s
# 650:	learn: 0.3163708	total: 27.7s	remaining: 14.8s
# 651:	learn: 0.3162347	total: 27.7s	remaining: 14.8s
# 652:	learn: 0.3161565	total: 27.8s	remaining: 14.8s
# 653:	learn: 0.3160783	total: 27.8s	remaining: 14.7s
# 654:	learn: 0.3159471	total: 27.8s	remaining: 14.7s
# 655:	learn: 0.3158686	total: 27.9s	remaining: 14.6s
# 656:	learn: 0.3158021	total: 27.9s	remaining: 14.6s
# 657:	learn: 0.3157258	total: 27.9s	remaining: 14.5s
# 658:	learn: 0.3156553	total: 28s	remaining: 14.5s
# 659:	learn: 0.3155476	total: 28s	remaining: 14.4s
# 660:	learn: 0.3154868	total: 28s	remaining: 14.4s
# 661:	learn: 0.3153990	total: 28.1s	remaining: 14.3s
# 662:	learn: 0.3153591	total: 28.1s	remaining: 14.3s
# 663:	learn: 0.3153015	total: 28.1s	remaining: 14.2s
# 664:	learn: 0.3152574	total: 28.2s	remaining: 14.2s
# 665:	learn: 0.3152070	total: 28.2s	remaining: 14.2s
# 666:	learn: 0.3151741	total: 28.2s	remaining: 14.1s
# 667:	learn: 0.3150998	total: 28.3s	remaining: 14.1s
# 668:	learn: 0.3149626	total: 28.3s	remaining: 14s
# 669:	learn: 0.3148751	total: 28.3s	remaining: 14s
# 670:	learn: 0.3147756	total: 28.4s	remaining: 13.9s
# 671:	learn: 0.3147197	total: 28.4s	remaining: 13.9s
# 672:	learn: 0.3146114	total: 28.4s	remaining: 13.8s
# 673:	learn: 0.3145164	total: 28.5s	remaining: 13.8s
# 674:	learn: 0.3144409	total: 28.5s	remaining: 13.7s
# 675:	learn: 0.3143799	total: 28.6s	remaining: 13.7s
# 676:	learn: 0.3142967	total: 28.6s	remaining: 13.6s
# 677:	learn: 0.3142048	total: 28.6s	remaining: 13.6s
# 678:	learn: 0.3141284	total: 28.7s	remaining: 13.5s
# 679:	learn: 0.3140518	total: 28.7s	remaining: 13.5s
# 680:	learn: 0.3139750	total: 28.7s	remaining: 13.5s
# 681:	learn: 0.3139483	total: 28.7s	remaining: 13.4s
# 682:	learn: 0.3138784	total: 28.8s	remaining: 13.4s
# 683:	learn: 0.3138393	total: 28.8s	remaining: 13.3s
# 684:	learn: 0.3137897	total: 28.8s	remaining: 13.3s
# 685:	learn: 0.3136853	total: 28.9s	remaining: 13.2s
# 686:	learn: 0.3135827	total: 28.9s	remaining: 13.2s
# 687:	learn: 0.3135329	total: 28.9s	remaining: 13.1s
# 688:	learn: 0.3134703	total: 29s	remaining: 13.1s
# 689:	learn: 0.3134154	total: 29s	remaining: 13s
# 690:	learn: 0.3133562	total: 29.1s	remaining: 13s
# 691:	learn: 0.3132690	total: 29.1s	remaining: 12.9s
# 692:	learn: 0.3131162	total: 29.1s	remaining: 12.9s
# 693:	learn: 0.3130386	total: 29.1s	remaining: 12.9s
# 694:	learn: 0.3129591	total: 29.2s	remaining: 12.8s
# 695:	learn: 0.3128918	total: 29.2s	remaining: 12.8s
# 696:	learn: 0.3127935	total: 29.2s	remaining: 12.7s
# 697:	learn: 0.3127359	total: 29.3s	remaining: 12.7s
# 698:	learn: 0.3126557	total: 29.3s	remaining: 12.6s
# 699:	learn: 0.3125450	total: 29.3s	remaining: 12.6s
# 700:	learn: 0.3123776	total: 29.4s	remaining: 12.5s
# 701:	learn: 0.3123009	total: 29.4s	remaining: 12.5s
# 702:	learn: 0.3122447	total: 29.4s	remaining: 12.4s
# 703:	learn: 0.3121679	total: 29.5s	remaining: 12.4s
# 704:	learn: 0.3121188	total: 29.5s	remaining: 12.4s
# 705:	learn: 0.3119881	total: 29.6s	remaining: 12.3s
# 706:	learn: 0.3118911	total: 29.6s	remaining: 12.3s
# 707:	learn: 0.3118398	total: 29.6s	remaining: 12.2s
# 708:	learn: 0.3117323	total: 29.7s	remaining: 12.2s
# 709:	learn: 0.3116523	total: 29.7s	remaining: 12.1s
# 710:	learn: 0.3115705	total: 29.7s	remaining: 12.1s
# 711:	learn: 0.3115052	total: 29.8s	remaining: 12s
# 712:	learn: 0.3114361	total: 29.8s	remaining: 12s
# 713:	learn: 0.3113918	total: 29.8s	remaining: 12s
# 714:	learn: 0.3113077	total: 29.9s	remaining: 11.9s
# 715:	learn: 0.3112630	total: 29.9s	remaining: 11.9s
# 716:	learn: 0.3112022	total: 29.9s	remaining: 11.8s
# 717:	learn: 0.3111165	total: 30s	remaining: 11.8s
# 718:	learn: 0.3110538	total: 30s	remaining: 11.7s
# 719:	learn: 0.3109397	total: 30s	remaining: 11.7s
# 720:	learn: 0.3108877	total: 30.1s	remaining: 11.6s
# 721:	learn: 0.3107977	total: 30.1s	remaining: 11.6s
# 722:	learn: 0.3107178	total: 30.1s	remaining: 11.5s
# 723:	learn: 0.3106234	total: 30.2s	remaining: 11.5s
# 724:	learn: 0.3105343	total: 30.2s	remaining: 11.5s
# 725:	learn: 0.3104607	total: 30.2s	remaining: 11.4s
# 726:	learn: 0.3103972	total: 30.3s	remaining: 11.4s
# 727:	learn: 0.3103546	total: 30.3s	remaining: 11.3s
# 728:	learn: 0.3102273	total: 30.3s	remaining: 11.3s
# 729:	learn: 0.3101530	total: 30.4s	remaining: 11.2s
# 730:	learn: 0.3100704	total: 30.4s	remaining: 11.2s
# 731:	learn: 0.3099756	total: 30.4s	remaining: 11.1s
# 732:	learn: 0.3099111	total: 30.5s	remaining: 11.1s
# 733:	learn: 0.3098581	total: 30.5s	remaining: 11.1s
# 734:	learn: 0.3097210	total: 30.5s	remaining: 11s
# 735:	learn: 0.3096773	total: 30.6s	remaining: 11s
# 736:	learn: 0.3096063	total: 30.6s	remaining: 10.9s
# 737:	learn: 0.3095485	total: 30.7s	remaining: 10.9s
# 738:	learn: 0.3094775	total: 30.7s	remaining: 10.8s
# 739:	learn: 0.3094086	total: 30.7s	remaining: 10.8s
# 740:	learn: 0.3093132	total: 30.8s	remaining: 10.8s
# 741:	learn: 0.3091476	total: 30.8s	remaining: 10.7s
# 742:	learn: 0.3090359	total: 30.8s	remaining: 10.7s
# 743:	learn: 0.3089329	total: 30.9s	remaining: 10.6s
# 744:	learn: 0.3088314	total: 30.9s	remaining: 10.6s
# 745:	learn: 0.3087011	total: 30.9s	remaining: 10.5s
# 746:	learn: 0.3086222	total: 31.1s	remaining: 10.5s
# 747:	learn: 0.3085407	total: 31.2s	remaining: 10.5s
# 748:	learn: 0.3084510	total: 31.3s	remaining: 10.5s
# 749:	learn: 0.3083743	total: 31.5s	remaining: 10.5s
# 750:	learn: 0.3082586	total: 31.8s	remaining: 10.6s
# 751:	learn: 0.3082002	total: 32.1s	remaining: 10.6s
# 752:	learn: 0.3081390	total: 32.2s	remaining: 10.6s
# 753:	learn: 0.3080135	total: 32.4s	remaining: 10.6s
# 754:	learn: 0.3079352	total: 32.5s	remaining: 10.5s
# 755:	learn: 0.3078969	total: 32.6s	remaining: 10.5s
# 756:	learn: 0.3078379	total: 32.6s	remaining: 10.5s
# 757:	learn: 0.3077922	total: 32.7s	remaining: 10.4s
# 758:	learn: 0.3077287	total: 32.9s	remaining: 10.5s
# 759:	learn: 0.3076875	total: 33.2s	remaining: 10.5s
# 760:	learn: 0.3076007	total: 33.4s	remaining: 10.5s
# 761:	learn: 0.3074890	total: 33.6s	remaining: 10.5s
# 762:	learn: 0.3074275	total: 33.8s	remaining: 10.5s
# 763:	learn: 0.3073089	total: 34.1s	remaining: 10.5s
# 764:	learn: 0.3072337	total: 34.3s	remaining: 10.5s
# 765:	learn: 0.3071952	total: 34.4s	remaining: 10.5s
# 766:	learn: 0.3071474	total: 34.5s	remaining: 10.5s
# 767:	learn: 0.3070743	total: 34.6s	remaining: 10.4s
# 768:	learn: 0.3069886	total: 34.6s	remaining: 10.4s
# 769:	learn: 0.3068962	total: 34.7s	remaining: 10.4s
# 770:	learn: 0.3068303	total: 34.7s	remaining: 10.3s
# 771:	learn: 0.3067882	total: 34.8s	remaining: 10.3s
# 772:	learn: 0.3067144	total: 34.9s	remaining: 10.3s
# 773:	learn: 0.3066434	total: 35s	remaining: 10.2s
# 774:	learn: 0.3065831	total: 35s	remaining: 10.2s
# 775:	learn: 0.3065311	total: 35.1s	remaining: 10.1s
# 776:	learn: 0.3064537	total: 35.2s	remaining: 10.1s
# 777:	learn: 0.3063375	total: 35.3s	remaining: 10.1s
# 778:	learn: 0.3062691	total: 35.4s	remaining: 10s
# 779:	learn: 0.3061950	total: 35.4s	remaining: 9.99s
# 780:	learn: 0.3061049	total: 35.5s	remaining: 9.96s
# 781:	learn: 0.3060128	total: 35.6s	remaining: 9.92s
# 782:	learn: 0.3059634	total: 35.6s	remaining: 9.88s
# 783:	learn: 0.3058881	total: 35.7s	remaining: 9.84s
# 784:	learn: 0.3058152	total: 35.8s	remaining: 9.8s
# 785:	learn: 0.3057454	total: 35.8s	remaining: 9.76s
# 786:	learn: 0.3056762	total: 35.9s	remaining: 9.72s
# 787:	learn: 0.3055877	total: 36s	remaining: 9.68s
# 788:	learn: 0.3055189	total: 36.1s	remaining: 9.64s
# 789:	learn: 0.3054392	total: 36.2s	remaining: 9.61s
# 790:	learn: 0.3053351	total: 36.2s	remaining: 9.57s
# 791:	learn: 0.3052252	total: 36.3s	remaining: 9.53s
# 792:	learn: 0.3051485	total: 36.4s	remaining: 9.5s
# 793:	learn: 0.3050567	total: 36.5s	remaining: 9.46s
# 794:	learn: 0.3050080	total: 36.5s	remaining: 9.42s
# 795:	learn: 0.3049528	total: 36.6s	remaining: 9.38s
# 796:	learn: 0.3048648	total: 36.7s	remaining: 9.34s
# 797:	learn: 0.3047927	total: 36.8s	remaining: 9.3s
# 798:	learn: 0.3047247	total: 36.8s	remaining: 9.27s
# 799:	learn: 0.3046588	total: 36.9s	remaining: 9.23s
# 800:	learn: 0.3046012	total: 37s	remaining: 9.2s
# 801:	learn: 0.3045528	total: 37.1s	remaining: 9.16s
# 802:	learn: 0.3045030	total: 37.2s	remaining: 9.12s
# 803:	learn: 0.3044360	total: 37.2s	remaining: 9.08s
# 804:	learn: 0.3043736	total: 37.3s	remaining: 9.04s
# 805:	learn: 0.3043048	total: 37.4s	remaining: 8.99s
# 806:	learn: 0.3042442	total: 37.4s	remaining: 8.95s
# 807:	learn: 0.3042070	total: 37.5s	remaining: 8.91s
# 808:	learn: 0.3041623	total: 37.5s	remaining: 8.86s
# 809:	learn: 0.3041143	total: 37.5s	remaining: 8.81s
# 810:	learn: 0.3040668	total: 37.6s	remaining: 8.76s
# 811:	learn: 0.3040164	total: 37.6s	remaining: 8.71s
# 812:	learn: 0.3039356	total: 37.6s	remaining: 8.66s
# 813:	learn: 0.3038593	total: 37.7s	remaining: 8.61s
# 814:	learn: 0.3037953	total: 37.7s	remaining: 8.56s
# 815:	learn: 0.3037107	total: 37.7s	remaining: 8.51s
# 816:	learn: 0.3036811	total: 37.8s	remaining: 8.46s
# 817:	learn: 0.3036132	total: 37.8s	remaining: 8.41s
# 818:	learn: 0.3035251	total: 37.9s	remaining: 8.37s
# 819:	learn: 0.3034655	total: 37.9s	remaining: 8.32s
# 820:	learn: 0.3033849	total: 37.9s	remaining: 8.27s
# 821:	learn: 0.3033139	total: 38s	remaining: 8.22s
# 822:	learn: 0.3032120	total: 38s	remaining: 8.17s
# 823:	learn: 0.3031398	total: 38s	remaining: 8.13s
# 824:	learn: 0.3030420	total: 38.1s	remaining: 8.08s
# 825:	learn: 0.3029602	total: 38.1s	remaining: 8.03s
# 826:	learn: 0.3028735	total: 38.1s	remaining: 7.98s
# 827:	learn: 0.3028214	total: 38.2s	remaining: 7.93s
# 828:	learn: 0.3027555	total: 38.2s	remaining: 7.88s
# 829:	learn: 0.3027097	total: 38.2s	remaining: 7.83s
# 830:	learn: 0.3025874	total: 38.3s	remaining: 7.78s
# 831:	learn: 0.3025460	total: 38.3s	remaining: 7.73s
# 832:	learn: 0.3024772	total: 38.3s	remaining: 7.69s
# 833:	learn: 0.3024099	total: 38.4s	remaining: 7.64s
# 834:	learn: 0.3023645	total: 38.4s	remaining: 7.59s
# 835:	learn: 0.3023333	total: 38.4s	remaining: 7.54s
# 836:	learn: 0.3022955	total: 38.5s	remaining: 7.49s
# 837:	learn: 0.3022632	total: 38.5s	remaining: 7.44s
# 838:	learn: 0.3021734	total: 38.5s	remaining: 7.4s
# 839:	learn: 0.3021490	total: 38.6s	remaining: 7.35s
# 840:	learn: 0.3021004	total: 38.6s	remaining: 7.3s
# 841:	learn: 0.3020134	total: 38.6s	remaining: 7.25s
# 842:	learn: 0.3019491	total: 38.7s	remaining: 7.2s
# 843:	learn: 0.3019044	total: 38.7s	remaining: 7.16s
# 844:	learn: 0.3018158	total: 38.7s	remaining: 7.11s
# 845:	learn: 0.3017684	total: 38.8s	remaining: 7.06s
# 846:	learn: 0.3017261	total: 38.8s	remaining: 7.01s
# 847:	learn: 0.3016584	total: 38.9s	remaining: 6.96s
# 848:	learn: 0.3016195	total: 38.9s	remaining: 6.92s
# 849:	learn: 0.3015201	total: 38.9s	remaining: 6.87s
# 850:	learn: 0.3014337	total: 39s	remaining: 6.82s
# 851:	learn: 0.3013993	total: 39s	remaining: 6.77s
# 852:	learn: 0.3013410	total: 39s	remaining: 6.73s
# 853:	learn: 0.3012885	total: 39.1s	remaining: 6.68s
# 854:	learn: 0.3012142	total: 39.1s	remaining: 6.63s
# 855:	learn: 0.3011380	total: 39.1s	remaining: 6.58s
# 856:	learn: 0.3010938	total: 39.2s	remaining: 6.54s
# 857:	learn: 0.3010346	total: 39.2s	remaining: 6.49s
# 858:	learn: 0.3009792	total: 39.2s	remaining: 6.44s
# 859:	learn: 0.3009373	total: 39.3s	remaining: 6.39s
# 860:	learn: 0.3008282	total: 39.3s	remaining: 6.35s
# 861:	learn: 0.3007686	total: 39.4s	remaining: 6.3s
# 862:	learn: 0.3006929	total: 39.4s	remaining: 6.25s
# 863:	learn: 0.3006340	total: 39.4s	remaining: 6.2s
# 864:	learn: 0.3005225	total: 39.5s	remaining: 6.16s
# 865:	learn: 0.3004695	total: 39.5s	remaining: 6.11s
# 866:	learn: 0.3004220	total: 39.5s	remaining: 6.06s
# 867:	learn: 0.3003064	total: 39.6s	remaining: 6.01s
# 868:	learn: 0.3002311	total: 39.6s	remaining: 5.97s
# 869:	learn: 0.3001284	total: 39.6s	remaining: 5.92s
# 870:	learn: 0.3000496	total: 39.7s	remaining: 5.87s
# 871:	learn: 0.3000010	total: 39.7s	remaining: 5.83s
# 872:	learn: 0.2998876	total: 39.7s	remaining: 5.78s
# 873:	learn: 0.2998358	total: 39.8s	remaining: 5.73s
# 874:	learn: 0.2997822	total: 39.8s	remaining: 5.69s
# 875:	learn: 0.2997552	total: 39.8s	remaining: 5.64s
# 876:	learn: 0.2997184	total: 39.9s	remaining: 5.59s
# 877:	learn: 0.2996232	total: 39.9s	remaining: 5.55s
# 878:	learn: 0.2994633	total: 40s	remaining: 5.5s
# 879:	learn: 0.2993465	total: 40s	remaining: 5.45s
# 880:	learn: 0.2992900	total: 40s	remaining: 5.41s
# 881:	learn: 0.2992313	total: 40.1s	remaining: 5.36s
# 882:	learn: 0.2991520	total: 40.1s	remaining: 5.32s
# 883:	learn: 0.2990382	total: 40.1s	remaining: 5.27s
# 884:	learn: 0.2989881	total: 40.2s	remaining: 5.22s
# 885:	learn: 0.2989086	total: 40.2s	remaining: 5.17s
# 886:	learn: 0.2988541	total: 40.2s	remaining: 5.13s
# 887:	learn: 0.2987274	total: 40.3s	remaining: 5.08s
# 888:	learn: 0.2986381	total: 40.3s	remaining: 5.03s
# 889:	learn: 0.2985734	total: 40.4s	remaining: 4.99s
# 890:	learn: 0.2985215	total: 40.4s	remaining: 4.94s
# 891:	learn: 0.2984644	total: 40.4s	remaining: 4.89s
# 892:	learn: 0.2984126	total: 40.5s	remaining: 4.85s
# 893:	learn: 0.2983713	total: 40.5s	remaining: 4.8s
# 894:	learn: 0.2983422	total: 40.5s	remaining: 4.75s
# 895:	learn: 0.2983197	total: 40.6s	remaining: 4.71s
# 896:	learn: 0.2982604	total: 40.6s	remaining: 4.66s
# 897:	learn: 0.2982101	total: 40.6s	remaining: 4.61s
# 898:	learn: 0.2981529	total: 40.7s	remaining: 4.57s
# 899:	learn: 0.2980693	total: 40.7s	remaining: 4.52s
# 900:	learn: 0.2980146	total: 40.7s	remaining: 4.47s
# 901:	learn: 0.2979654	total: 40.8s	remaining: 4.43s
# 902:	learn: 0.2978673	total: 40.8s	remaining: 4.38s
# 903:	learn: 0.2978123	total: 40.8s	remaining: 4.33s
# 904:	learn: 0.2977661	total: 40.9s	remaining: 4.29s
# 905:	learn: 0.2976818	total: 40.9s	remaining: 4.24s
# 906:	learn: 0.2976306	total: 40.9s	remaining: 4.2s
# 907:	learn: 0.2975318	total: 41s	remaining: 4.15s
# 908:	learn: 0.2974881	total: 41s	remaining: 4.1s
# 909:	learn: 0.2974460	total: 41s	remaining: 4.06s
# 910:	learn: 0.2973879	total: 41.1s	remaining: 4.01s
# 911:	learn: 0.2973331	total: 41.1s	remaining: 3.97s
# 912:	learn: 0.2972367	total: 41.1s	remaining: 3.92s
# 913:	learn: 0.2971929	total: 41.2s	remaining: 3.87s
# 914:	learn: 0.2971542	total: 41.2s	remaining: 3.83s
# 915:	learn: 0.2970877	total: 41.2s	remaining: 3.78s
# 916:	learn: 0.2970504	total: 41.3s	remaining: 3.74s
# 917:	learn: 0.2969582	total: 41.3s	remaining: 3.69s
# 918:	learn: 0.2968830	total: 41.4s	remaining: 3.64s
# 919:	learn: 0.2968161	total: 41.4s	remaining: 3.6s
# 920:	learn: 0.2967801	total: 41.4s	remaining: 3.55s
# 921:	learn: 0.2967408	total: 41.4s	remaining: 3.51s
# 922:	learn: 0.2967106	total: 41.5s	remaining: 3.46s
# 923:	learn: 0.2966607	total: 41.5s	remaining: 3.41s
# 924:	learn: 0.2965978	total: 41.5s	remaining: 3.37s
# 925:	learn: 0.2965667	total: 41.6s	remaining: 3.32s
# 926:	learn: 0.2965098	total: 41.6s	remaining: 3.28s
# 927:	learn: 0.2964024	total: 41.6s	remaining: 3.23s
# 928:	learn: 0.2963441	total: 41.7s	remaining: 3.18s
# 929:	learn: 0.2962585	total: 41.7s	remaining: 3.14s
# 930:	learn: 0.2961973	total: 41.7s	remaining: 3.09s
# 931:	learn: 0.2961335	total: 41.8s	remaining: 3.05s
# 932:	learn: 0.2960714	total: 41.8s	remaining: 3s
# 933:	learn: 0.2960375	total: 41.8s	remaining: 2.96s
# 934:	learn: 0.2959978	total: 41.9s	remaining: 2.91s
# 935:	learn: 0.2959342	total: 41.9s	remaining: 2.87s
# 936:	learn: 0.2958929	total: 41.9s	remaining: 2.82s
# 937:	learn: 0.2958401	total: 42s	remaining: 2.77s
# 938:	learn: 0.2957996	total: 42s	remaining: 2.73s
# 939:	learn: 0.2957284	total: 42s	remaining: 2.68s
# 940:	learn: 0.2956799	total: 42.1s	remaining: 2.64s
# 941:	learn: 0.2956082	total: 42.1s	remaining: 2.59s
# 942:	learn: 0.2955359	total: 42.1s	remaining: 2.55s
# 943:	learn: 0.2954988	total: 42.2s	remaining: 2.5s
# 944:	learn: 0.2954254	total: 42.2s	remaining: 2.46s
# 945:	learn: 0.2953939	total: 42.3s	remaining: 2.41s
# 946:	learn: 0.2953570	total: 42.3s	remaining: 2.37s
# 947:	learn: 0.2952711	total: 42.3s	remaining: 2.32s
# 948:	learn: 0.2951542	total: 42.3s	remaining: 2.27s
# 949:	learn: 0.2950638	total: 42.4s	remaining: 2.23s
# 950:	learn: 0.2950025	total: 42.4s	remaining: 2.19s
# 951:	learn: 0.2949650	total: 42.4s	remaining: 2.14s
# 952:	learn: 0.2948961	total: 42.5s	remaining: 2.1s
# 953:	learn: 0.2948276	total: 42.5s	remaining: 2.05s
# 954:	learn: 0.2947860	total: 42.5s	remaining: 2s
# 955:	learn: 0.2947313	total: 42.6s	remaining: 1.96s
# 956:	learn: 0.2946415	total: 42.6s	remaining: 1.91s
# 957:	learn: 0.2945984	total: 42.6s	remaining: 1.87s
# 958:	learn: 0.2945460	total: 42.7s	remaining: 1.82s
# 959:	learn: 0.2944979	total: 42.7s	remaining: 1.78s
# 960:	learn: 0.2944446	total: 42.8s	remaining: 1.73s
# 961:	learn: 0.2943810	total: 42.8s	remaining: 1.69s
# 962:	learn: 0.2943267	total: 42.8s	remaining: 1.64s
# 963:	learn: 0.2943097	total: 42.8s	remaining: 1.6s
# 964:	learn: 0.2942772	total: 42.9s	remaining: 1.55s
# 965:	learn: 0.2942291	total: 42.9s	remaining: 1.51s
# 966:	learn: 0.2941602	total: 42.9s	remaining: 1.47s
# 967:	learn: 0.2941046	total: 43s	remaining: 1.42s
# 968:	learn: 0.2940430	total: 43s	remaining: 1.38s
# 969:	learn: 0.2939927	total: 43s	remaining: 1.33s
# 970:	learn: 0.2939323	total: 43.1s	remaining: 1.29s
# 971:	learn: 0.2938946	total: 43.1s	remaining: 1.24s
# 972:	learn: 0.2938448	total: 43.2s	remaining: 1.2s
# 973:	learn: 0.2937949	total: 43.2s	remaining: 1.15s
# 974:	learn: 0.2937548	total: 43.2s	remaining: 1.11s
# 975:	learn: 0.2936931	total: 43.3s	remaining: 1.06s
# 976:	learn: 0.2936530	total: 43.3s	remaining: 1.02s
# 977:	learn: 0.2935776	total: 43.3s	remaining: 974ms
# 978:	learn: 0.2935354	total: 43.3s	remaining: 930ms
# 979:	learn: 0.2934500	total: 43.4s	remaining: 885ms
# 980:	learn: 0.2933892	total: 43.4s	remaining: 841ms
# 981:	learn: 0.2933028	total: 43.4s	remaining: 796ms
# 982:	learn: 0.2932415	total: 43.5s	remaining: 752ms
# 983:	learn: 0.2931726	total: 43.5s	remaining: 707ms
# 984:	learn: 0.2931027	total: 43.5s	remaining: 663ms
# 985:	learn: 0.2929821	total: 43.6s	remaining: 619ms
# 986:	learn: 0.2929059	total: 43.6s	remaining: 574ms
# 987:	learn: 0.2928305	total: 43.6s	remaining: 530ms
# 988:	learn: 0.2927479	total: 43.7s	remaining: 486ms
# 989:	learn: 0.2926940	total: 43.7s	remaining: 441ms
# 990:	learn: 0.2926430	total: 43.7s	remaining: 397ms
# 991:	learn: 0.2925942	total: 43.8s	remaining: 353ms
# 992:	learn: 0.2925305	total: 43.8s	remaining: 309ms
# 993:	learn: 0.2924574	total: 43.8s	remaining: 265ms
# 994:	learn: 0.2923830	total: 43.9s	remaining: 220ms
# 995:	learn: 0.2923114	total: 43.9s	remaining: 176ms
# 996:	learn: 0.2922751	total: 43.9s	remaining: 132ms
# 997:	learn: 0.2922139	total: 44s	remaining: 88.1ms
# 998:	learn: 0.2921432	total: 44s	remaining: 44.1ms
# 999:	learn: 0.2920234	total: 44s	remaining: 0us
# Model: <catboost.core.CatBoostClassifier object at 0x7cdb92e862f0>
# Training: 0.9494756302523826
# Validation: 0.9490102400120789
#
# [LightGBM] [Info] Number of positive: 73859, number of negative: 73833
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003467 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 328
# [LightGBM] [Info] Number of data points in the train set: 147692, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500088 -> initscore=0.000352
# [LightGBM] [Info] Start training from score 0.000352
# Model: LGBMClassifier()
# Training: 0.9261044661267526
# Validation: 0.929719221996344

# %% [markdown]
# For probability prediction the accuracy of the logistic regression model is quite low, whereas the XGBClassifier and others are performing excellently, achieving a 94% validation accuracy without any signs of overfitting.
# Evaluating scores using binary predictions and probability predictions results in different scores for the same set of predictions.

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc
# Defining the models to be evaluated
model_list2 = [LogisticRegression(), DecisionTreeClassifier(), XGBClassifier(), HistGradientBoostingClassifier(),
                CatBoostClassifier(verbose=0), lgb.LGBMClassifier(n_estimators=100)]

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.ravel()

# Iterating over each model to train and evaluate
for i, model in enumerate(model_list2):
    # Fit the model on the training data
    model.fit(X_train, Y_train)

    # Printing model details and evaluation metrics
    print(f'Model: {model}')
    train_predictions = model.predict_proba(X_train)[:, 1]
    val_predictions = model.predict_proba(X_val)[:, 1]

    # Calculate ROC curve and AUC
    fpr, tpr, thresholds = roc_curve(Y_val, val_predictions)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve in the corresponding subplot
    axes[i].plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    axes[i].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    axes[i].set_xlim([0.0, 1.0])
    axes[i].set_ylim([0.0, 1.05])
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].set_title(f'ROC Curve for {model.__class__.__name__}')
    axes[i].legend(loc="lower right")

plt.tight_layout()
plt.show()
# Out:
# Model: LogisticRegression()
# Model: DecisionTreeClassifier()
# Model: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# Model: HistGradientBoostingClassifier()
# Model: <catboost.core.CatBoostClassifier object at 0x7cdb950f90f0>
# [LightGBM] [Info] Number of positive: 73859, number of negative: 73833
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004903 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 328
# [LightGBM] [Info] Number of data points in the train set: 147692, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500088 -> initscore=0.000352
# [LightGBM] [Info] Start training from score 0.000352
# Model: LGBMClassifier()

# %% [markdown]
# omitting logistic regression, decision tree and catboost.

# %%
from sklearn.metrics import roc_auc_score
# Defining the models to be evaluated
model_list3 = [ XGBClassifier(), HistGradientBoostingClassifier(), lgb.LGBMClassifier(n_estimators=100)]

# Iterating over each model to train and evaluate
for model in model_list3:
    # Fit the model on the training data
    model.fit(X_train, Y_train)

    # Printing model details and evaluation metrics
    print(f'Model: {model}')
    train_predictions = model.predict_proba(X_train)[:, 1]
    val_predictions = model.predict_proba(X_val)[:, 1]
    print('Training:', roc_auc_score(Y_train, train_predictions))
    print('Validation:', roc_auc_score(Y_val, val_predictions))
    print()
# Out:
# Model: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# Training: 0.951692506043518
# Validation: 0.9489131782862136
#
# Model: HistGradientBoostingClassifier()
# Training: 0.9248848679962351
# Validation: 0.9282686884264676
#
# [LightGBM] [Info] Number of positive: 73859, number of negative: 73833
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002768 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 328
# [LightGBM] [Info] Number of data points in the train set: 147692, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500088 -> initscore=0.000352
# [LightGBM] [Info] Start training from score 0.000352
# Model: LGBMClassifier()
# Training: 0.9261044661267526
# Validation: 0.929719221996344

# %% [markdown]
# **Model enesembling:**

# %% [markdown]
# Ensemble model_list2:

# %%
# Ensemble model_list2

# Creating an empty list to store predictions from individual models
val_predictions = []

# Iterating over each model in model_list2
for model in model_list2:
  # Fitting the model on the training data
  model.fit(X_train, Y_train)

  # Getting predictions from the model
  predictions = model.predict_proba(X_val)[:, 1]

  # Appending the predictions to the list
  val_predictions.append(predictions)

# Calculating the average predictions across all models
avg_predictions = np.mean(val_predictions, axis=0)

# Calculating and printing the ROC AUC score for the ensemble
print('Ensemble Model:')
print('Training ROC AUC:', roc_auc_score(Y_train, train_predictions))
print('Validation ROC AUC:', roc_auc_score(Y_val, avg_predictions))
# Out:
# [LightGBM] [Info] Number of positive: 73859, number of negative: 73833
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004264 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 328
# [LightGBM] [Info] Number of data points in the train set: 147692, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500088 -> initscore=0.000352
# [LightGBM] [Info] Start training from score 0.000352
# Ensemble Model:
# Training ROC AUC: 0.9261044661267526
# Validation ROC AUC: 0.9874305065004395

# %%
# Plotting ROC curve for the ensemble model_list2
fpr, tpr, thresholds = metrics.roc_curve(Y_val, avg_predictions) # Changed val_predictions to avg_predictions
roc_auc = metrics.auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic model_list2')
plt.legend(loc="lower right")
plt.show()

# %%
# Ensemble model_list3

# Creating an empty list to store predictions from individual models
val_predictions3 = []

# Iterating over each model in model_list3
for model in model_list3:
  # Fitting the model on the training data
  model.fit(X_train, Y_train)

  # Getting predictions from the model
  predictions = model.predict_proba(X_val)[:, 1]

  # Appending the predictions to the list
  val_predictions3.append(predictions)

# Calculating the average predictions across all models
avg_predictions = np.mean(val_predictions3, axis=0)

# Calculating and printing the ROC AUC score for the ensemble
print('Ensemble Model:')
print('Training ROC AUC:', roc_auc_score(Y_train, train_predictions))
print('Validation ROC AUC:', roc_auc_score(Y_val, avg_predictions))
# Out:
# [LightGBM] [Info] Number of positive: 73859, number of negative: 73833
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002775 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 328
# [LightGBM] [Info] Number of data points in the train set: 147692, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500088 -> initscore=0.000352
# [LightGBM] [Info] Start training from score 0.000352
# Ensemble Model:
# Training ROC AUC: 0.9261044661267526
# Validation ROC AUC: 0.9421691857779407

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np # Added import for np.mean

# Plotting ROC curve for the ensemble model
# Calculate the average predictions across all models
avg_predictions = np.mean(val_predictions3, axis=0)

fpr, tpr, thresholds = metrics.roc_curve(Y_val, avg_predictions) # Changed val_predictions3 to avg_predictions
roc_auc = metrics.auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic model_list3')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Test dataset:**

# %%
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/energy-anomaly-detection/test.csv', index_col=0)
test = split_timestamp(test)
test = extract_month_day(test)
test['weekend'] = test.apply(lambda x:\
                               is_weekend(int(2016),int(x['month']),int(x['day'])),axis=1)
test.head()
# Out:
#         building_id  meter_reading  hour  month  day  weekend
# row_id
# 0                18            NaN     0      1    1        0
# 1                19            NaN     0      1    1        0
# 2                26            NaN     0      1    1        0
# 3                38            NaN     0      1    1        0
# 4                39            NaN     0      1    1        0

# %%
test.shape
# Out:
# (1800567, 6)

# %%
test.isnull().sum()
# Out:
# building_id          0
# meter_reading    94864
# hour                 0
# month                0
# day                  0
# weekend              0
# dtype: int64

# %%
k = test.isnull().sum().sum()
plt.pie([k, test.shape[0]-k], labels=['Null', 'Filled']\
        , colors=sb.color_palette('Accent'), autopct='%.0f%%')
plt.show()

# %% [markdown]
# Approximately 5% of the meter_reading entries in the test data are null, which is comparable to the train data, where around 6% of the meter_reading entries are null.

# %% [markdown]
# **Imputing nulls:**

# %%
test = fill_missing_values(test)
test.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **6. Evaluation**

# %%
# Creating an empty list to store predictions from individual models
test_predictions = []

# Iterating over each model in model_list2
for model in model_list2:
  # Getting predictions from the model
  # Ensure the test data has the same number of features as the model was trained on
  predictions = model.predict_proba(test.iloc[:, :5])[:, 1] # Select the first 5 columns of the test data

  # Appending the predictions to the list
  test_predictions.append(predictions)

# Calculating the average predictions across all models
avg_predictions = np.mean(test_predictions, axis=0)

# Create a submission DataFrame
submission_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/energy-anomaly-detection/sample_submission.csv')
submission_df = pd.DataFrame({'row_id': range(len(avg_predictions)), 'anomaly': avg_predictions})

# Save the DataFrame to a CSV file named 'submission_ensemble2.csv'

submission_df.to_csv('submission_df.csv', index=False)
print(submission_df.head())
# Out:
#    row_id   anomaly
# 0       0  0.323905
# 1       1  0.325675
# 2       2  0.324996
# 3       3  0.323912
# 4       4  0.323938

# %%
ss = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/energy-anomaly-detection/sample_submission.csv')
ss['anomaly'] = predictions
ss.to_csv('Submission.csv', index=False)
ss.head()
# Out:
#    row_id   anomaly
# 0       0  0.500955
# 1       1  0.500955
# 2       2  0.500955
# 3       3  0.500955
# 4       4  0.500955
